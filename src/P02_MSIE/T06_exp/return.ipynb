# %%
import pickle
from P02_MSIE.T06_exp.vrptw_v9 import VRPTW
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
folder = "R_20251113_094016"
it = 62

# %%
with open(f"./save_models/{folder}/vrp_{it:05d}.pkl", "rb") as f:
    vrptw = pickle.load(f)

# %%
vrptw.global_solution_history
# Out:
# []

# %%
vrptw.current_cost
# Out:
# array([1000000., 1000000., 1000000., 1000000.])

# %%
plt.plot(vrptw.global_solution_history)
