# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
from P02_MSIE.T01_prototype_class.DE_IM_VRPTW_classV5_3 import VRPTW, SOL_UPPER_BOUND

# %%
class AIMH_ENV(gym.Env):
    def __init__(self, vrp):
        super().__init__()
        self.action_space = spaces.Box(
            low = np.array([0, 0, 0], dtype=np.float32), 
            high= np.array([5, 5, 1], dtype=np.float32), 
            shape=(3,),
            dtype=np.float32,
        )
            # order = [
        #     "best_solution",
        #     "F",
        #     "CR",
        #     "MG",
        #     "percent_convergence",
        #     "std_pop",
        #     "total_iteration",
        # ]
        self.observation_space = gym.spaces.Box(
            low=np.array([0, 0, 0, 0, 0, 0, 0], dtype=np.float32),
            high=np.array([SOL_UPPER_BOUND, 10, 10, 1, 1, 1, 1e5], dtype=np.float32),
            shape=(7,),  # 7 features
            dtype=np.float64,
        )
        self.vrp = vrp
        pass


    def _get_obs(self):
        
        state = self.vrp.get_current_state()
        obs = np.array(
            [
                np.float32(state["best_solution"]),
                np.float32(state["F"]),
                np.float32(state["CR"]),
                np.float32(state["MG"]),
                np.float32(state["percent_convergence"]),
                np.float32(state["std_pop"]),
                np.float32(state["total_iteration"]),
            ]
        )
        
        return obs
    
    def _get_info(self):
        """Compute auxiliary information for debugging.

        Returns:
            dict: Info in addition to the observation
        """
        return self.vrp.get_info()
    

    def reset(self, seed=None, options=None):
        # np.random.seed(seed or 42)
        self.vrp.reset()
        super().reset(seed=seed)
        observation = self._get_obs()
        info = self._get_info()
        return observation, info

    def step(self, action):
        self.vrp.action(action)
        self.vrp.evolve()
        reward = self.vrp.get_reward()
        if self.vrp.is_terminated():
            terminated = True
            truncated = True
        else:
            terminated = False
            truncated = False
        observation = self._get_obs()
        info = self._get_info()
        return observation, reward, terminated, truncated, info

# %%
AIMH_ENV(vrp=None).action_space.sample()
# Out:
# array([0.8214719 , 2.1108437 , 0.79488945], dtype=float32)

# %%
distance = (
    pd.read_excel(
        r"../../Source/rl_meta_test_data.xlsx", sheet_name="distance"
    )
    .fillna(9999999)
    .to_numpy()
)

df_vehicle = (
    pd.read_excel(
        r"../../Source/rl_meta_test_data.xlsx", sheet_name="vehicle"
    )
    .iloc[:, :2]
    .to_numpy(dtype=int)
)
vehicle = df_vehicle[0]

df_101 = pd.read_excel(
    r"../../Source/rl_meta_test_data.xlsx", sheet_name="customer"
).iloc[:, 3:]
demand = df_101.iloc[:, 0].to_numpy()
readyTime = df_101.iloc[:, 1].to_numpy()
dueDate = df_101.iloc[:, 2].to_numpy()
serviceTime = df_101.iloc[:, -1].to_numpy()

kwargs = {
    "distance": distance,
    "demand": demand,
    "readyTime": readyTime,
    "dueDate": dueDate,
    "serviceTime": serviceTime,
    "vehicle": vehicle,
}

dimensions = len(distance) - 1 + vehicle[0]
interval_it = 20
patience = 200
population_size = 4
bounds = np.array([[0, 1]] * dimensions)
F_rate = 0.5
CR_rate = 0.5
MG_rate = 0.5

vrptw = VRPTW(
    population_size=population_size,
    dimensions=dimensions,
    bounds=bounds,
    distance=distance,
    demand=demand,
    readyTime=readyTime,
    dueDate=dueDate,
    serviceTime=serviceTime,
    vehicle=vehicle,
    interval_it=interval_it,
    patience=patience,
)

# %%
obs, info = AIMH_ENV(vrp=vrptw).reset()
print(obs)
# Out:
# [1.00000e+06 5.00005e-01 5.00005e-01 5.00000e-01 0.00000e+00 0.00000e+00
#  0.00000e+00]

# %%
# TODO: Fix the environment to pass the checks
# UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Environment has issues: Deterministic step observations are not equivalent for the same seed and action


from gymnasium.utils.env_checker import check_env

env = AIMH_ENV(vrp=vrptw)

# This will catch many common issues
try:
    check_env(env)
    print("Environment passes all checks!")
except Exception as e:
    print(f"Environment has issues: {e}")
# Out:
# Environment passes all checks!
# c:\Users\admin\Coding\research\rl-meta-test\.venv\Lib\site-packages\gymnasium\utils\env_checker.py:333: UserWarning: WARN: For Box action spaces, we recommend using a symmetric and normalized space (range=[-1, 1] or [0, 1]). See https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html for more information.
#   logger.warn(
# c:\Users\admin\Coding\research\rl-meta-test\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float64, actual type: float32
#   logger.warn(
# c:\Users\admin\Coding\research\rl-meta-test\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float64, actual type: float32
#   logger.warn(
# c:\Users\admin\Coding\research\rl-meta-test\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# c:\Users\admin\Coding\research\rl-meta-test\.venv\Lib\site-packages\gymnasium\utils\env_checker.py:434: UserWarning: WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantiating the environment through `gymnasium.make`
#   logger.warn(

# %%
from stable_baselines3 import SAC

model = SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.8     |
# |    ep_rew_mean     | 34.5     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 166      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 75       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.9     |
# |    ep_rew_mean     | 34.4     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 102      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 143      |
# | train/             |          |
# |    actor_loss      | 36.5     |
# |    critic_loss     | 2.41e+05 |
# |    ent_coef        | 1.01     |
# |    ent_coef_loss   | -0.0641  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.7     |
# |    ep_rew_mean     | 31       |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 81       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 18.8     |
# |    critic_loss     | 192      |
# |    ent_coef        | 1.03     |
# |    ent_coef_loss   | -0.327   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.2     |
# |    ep_rew_mean     | 48.9     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 71       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 275      |
# | train/             |          |
# |    actor_loss      | 28.3     |
# |    critic_loss     | 118      |
# |    ent_coef        | 1.05     |
# |    ent_coef_loss   | -0.642   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 174      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.2     |
# |    ep_rew_mean     | 59.2     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 66       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 384      |
# | train/             |          |
# |    actor_loss      | 30.8     |
# |    critic_loss     | 191      |
# |    ent_coef        | 1.09     |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 283      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | 390      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 64       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 468      |
# | train/             |          |
# |    actor_loss      | 54.7     |
# |    critic_loss     | 4.56e+04 |
# |    ent_coef        | 1.12     |
# |    ent_coef_loss   | -1.51    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 367      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.8     |
# |    ep_rew_mean     | 339      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 62       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 553      |
# | train/             |          |
# |    actor_loss      | 16.1     |
# |    critic_loss     | 4.58e+04 |
# |    ent_coef        | 1.15     |
# |    ent_coef_loss   | -1.68    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 452      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | 306      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 61       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 636      |
# | train/             |          |
# |    actor_loss      | 29.7     |
# |    critic_loss     | 3.33e+03 |
# |    ent_coef        | 1.19     |
# |    ent_coef_loss   | -3.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 535      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 60       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 726      |
# | train/             |          |
# |    actor_loss      | 31.7     |
# |    critic_loss     | 882      |
# |    ent_coef        | 1.23     |
# |    ent_coef_loss   | -2.72    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 625      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 267      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 59       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 841      |
# | train/             |          |
# |    actor_loss      | 14.6     |
# |    critic_loss     | 1.54e+04 |
# |    ent_coef        | 1.27     |
# |    ent_coef_loss   | -2.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 740      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 247      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 59       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 933      |
# | train/             |          |
# |    actor_loss      | 47.1     |
# |    critic_loss     | 4.5e+04  |
# |    ent_coef        | 1.3      |
# |    ent_coef_loss   | -3.48    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 832      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | 322      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 58       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1040     |
# | train/             |          |
# |    actor_loss      | 15.5     |
# |    critic_loss     | 1.59e+04 |
# |    ent_coef        | 1.35     |
# |    ent_coef_loss   | -3.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 939      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 301      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 58       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1125     |
# | train/             |          |
# |    actor_loss      | 19       |
# |    critic_loss     | 462      |
# |    ent_coef        | 1.38     |
# |    ent_coef_loss   | -3.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1024     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 58       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | 23.6     |
# |    critic_loss     | 1.6e+04  |
# |    ent_coef        | 1.41     |
# |    ent_coef_loss   | -4.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 58       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1273     |
# | train/             |          |
# |    actor_loss      | 30.2     |
# |    critic_loss     | 1.58e+04 |
# |    ent_coef        | 1.44     |
# |    ent_coef_loss   | -4.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1172     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 58       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1364     |
# | train/             |          |
# |    actor_loss      | 25       |
# |    critic_loss     | 3.1e+04  |
# |    ent_coef        | 1.48     |
# |    ent_coef_loss   | -4.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1263     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 254      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 58       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 1427     |
# | train/             |          |
# |    actor_loss      | 25.7     |
# |    critic_loss     | 1.56e+04 |
# |    ent_coef        | 1.51     |
# |    ent_coef_loss   | -4.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1326     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 241      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 58       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1483     |
# | train/             |          |
# |    actor_loss      | 69.8     |
# |    critic_loss     | 3.42e+04 |
# |    ent_coef        | 1.54     |
# |    ent_coef_loss   | -7.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1382     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 229      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 58       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1550     |
# | train/             |          |
# |    actor_loss      | 159      |
# |    critic_loss     | 3.14e+05 |
# |    ent_coef        | 1.58     |
# |    ent_coef_loss   | -8.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1449     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 218      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 57       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 1608     |
# | train/             |          |
# |    actor_loss      | 115      |
# |    critic_loss     | 3.6e+04  |
# |    ent_coef        | 1.62     |
# |    ent_coef_loss   | -8.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1507     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.8     |
# |    ep_rew_mean     | 208      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 57       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 1662     |
# | train/             |          |
# |    actor_loss      | 66.4     |
# |    critic_loss     | 3.79e+03 |
# |    ent_coef        | 1.65     |
# |    ent_coef_loss   | -8.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1561     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 57       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 1725     |
# | train/             |          |
# |    actor_loss      | 64.8     |
# |    critic_loss     | 1.6e+04  |
# |    ent_coef        | 1.69     |
# |    ent_coef_loss   | -9.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1624     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.3     |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 56       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 1777     |
# | train/             |          |
# |    actor_loss      | 69.9     |
# |    critic_loss     | 1.63e+04 |
# |    ent_coef        | 1.72     |
# |    ent_coef_loss   | -9.64    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1676     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.1     |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 56       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 1838     |
# | train/             |          |
# |    actor_loss      | 76.9     |
# |    critic_loss     | 1.62e+04 |
# |    ent_coef        | 1.76     |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1737     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.9     |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 56       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 1894     |
# | train/             |          |
# |    actor_loss      | 84.2     |
# |    critic_loss     | 1.61e+04 |
# |    ent_coef        | 1.8      |
# |    ent_coef_loss   | -10.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1793     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.7     |
# |    ep_rew_mean     | 176      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 56       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 1946     |
# | train/             |          |
# |    actor_loss      | 86.9     |
# |    critic_loss     | 3.15e+04 |
# |    ent_coef        | 1.83     |
# |    ent_coef_loss   | -10.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1845     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.5     |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 55       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 1990     |
# | train/             |          |
# |    actor_loss      | 94.2     |
# |    critic_loss     | 1.93e+04 |
# |    ent_coef        | 1.86     |
# |    ent_coef_loss   | -10.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1889     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.5     |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 55       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 2049     |
# | train/             |          |
# |    actor_loss      | 102      |
# |    critic_loss     | 1.79e+04 |
# |    ent_coef        | 1.9      |
# |    ent_coef_loss   | -11.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1948     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.3     |
# |    ep_rew_mean     | 171      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 55       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2101     |
# | train/             |          |
# |    actor_loss      | 100      |
# |    critic_loss     | 3.13e+04 |
# |    ent_coef        | 1.93     |
# |    ent_coef_loss   | -11.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.7     |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 55       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2152     |
# | train/             |          |
# |    actor_loss      | 128      |
# |    critic_loss     | 1.75e+04 |
# |    ent_coef        | 1.96     |
# |    ent_coef_loss   | -11.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2051     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.3     |
# |    ep_rew_mean     | 86.2     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 55       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 2196     |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 2.5e+03  |
# |    ent_coef        | 1.99     |
# |    ent_coef_loss   | -12.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2095     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.1     |
# |    ep_rew_mean     | 85.9     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 54       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 2265     |
# | train/             |          |
# |    actor_loss      | 98.8     |
# |    critic_loss     | 1.68e+04 |
# |    ent_coef        | 2.04     |
# |    ent_coef_loss   | -9.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2164     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.2     |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 54       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 2360     |
# | train/             |          |
# |    actor_loss      | 93.3     |
# |    critic_loss     | 7.59e+04 |
# |    ent_coef        | 2.09     |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2259     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.3     |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 54       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 2459     |
# | train/             |          |
# |    actor_loss      | 123      |
# |    critic_loss     | 4.04e+05 |
# |    ent_coef        | 2.15     |
# |    ent_coef_loss   | -13.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2358     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.8     |
# |    ep_rew_mean     | 239      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 54       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 2520     |
# | train/             |          |
# |    actor_loss      | 106      |
# |    critic_loss     | 1.81e+04 |
# |    ent_coef        | 2.2      |
# |    ent_coef_loss   | -14.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2419     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.6     |
# |    ep_rew_mean     | 239      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 54       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 2597     |
# | train/             |          |
# |    actor_loss      | 190      |
# |    critic_loss     | 5.18e+03 |
# |    ent_coef        | 2.26     |
# |    ent_coef_loss   | -14.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2496     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.2     |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 53       |
# |    time_elapsed    | 49       |
# |    total_timesteps | 2662     |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 2.25e+03 |
# |    ent_coef        | 2.3      |
# |    ent_coef_loss   | -14.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2561     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 53       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 2723     |
# | train/             |          |
# |    actor_loss      | 133      |
# |    critic_loss     | 3e+04    |
# |    ent_coef        | 2.35     |
# |    ent_coef_loss   | -18.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2622     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.2     |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 53       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 2819     |
# | train/             |          |
# |    actor_loss      | 196      |
# |    critic_loss     | 1.81e+03 |
# |    ent_coef        | 2.44     |
# |    ent_coef_loss   | -20.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2718     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.1     |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 53       |
# |    time_elapsed    | 53       |
# |    total_timesteps | 2885     |
# | train/             |          |
# |    actor_loss      | 183      |
# |    critic_loss     | 1.72e+04 |
# |    ent_coef        | 2.51     |
# |    ent_coef_loss   | -20.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2784     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.9     |
# |    ep_rew_mean     | 193      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 53       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 2956     |
# | train/             |          |
# |    actor_loss      | 194      |
# |    critic_loss     | 9.66e+03 |
# |    ent_coef        | 2.58     |
# |    ent_coef_loss   | -22      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2855     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.9     |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 53       |
# |    time_elapsed    | 56       |
# |    total_timesteps | 3013     |
# | train/             |          |
# |    actor_loss      | 234      |
# |    critic_loss     | 2.98e+03 |
# |    ent_coef        | 2.64     |
# |    ent_coef_loss   | -22.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2912     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.3     |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 53       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 3109     |
# | train/             |          |
# |    actor_loss      | 199      |
# |    critic_loss     | 3.22e+04 |
# |    ent_coef        | 2.72     |
# |    ent_coef_loss   | -19.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3008     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.6     |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 53       |
# |    time_elapsed    | 60       |
# |    total_timesteps | 3208     |
# | train/             |          |
# |    actor_loss      | 166      |
# |    critic_loss     | 3.41e+03 |
# |    ent_coef        | 2.8      |
# |    ent_coef_loss   | -14.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3107     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.6     |
# |    ep_rew_mean     | 197      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 52       |
# |    time_elapsed    | 61       |
# |    total_timesteps | 3266     |
# | train/             |          |
# |    actor_loss      | 172      |
# |    critic_loss     | 1.78e+04 |
# |    ent_coef        | 2.84     |
# |    ent_coef_loss   | -13.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3165     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.6     |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 52       |
# |    time_elapsed    | 62       |
# |    total_timesteps | 3323     |
# | train/             |          |
# |    actor_loss      | 162      |
# |    critic_loss     | 1.72e+04 |
# |    ent_coef        | 2.88     |
# |    ent_coef_loss   | -12.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3222     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.5     |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 52       |
# |    time_elapsed    | 64       |
# |    total_timesteps | 3378     |
# | train/             |          |
# |    actor_loss      | 166      |
# |    critic_loss     | 2.99e+04 |
# |    ent_coef        | 2.91     |
# |    ent_coef_loss   | -12.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3277     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.7     |
# |    ep_rew_mean     | 203      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 52       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 3447     |
# | train/             |          |
# |    actor_loss      | 181      |
# |    critic_loss     | 3.33e+04 |
# |    ent_coef        | 2.95     |
# |    ent_coef_loss   | -11.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3346     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.1     |
# |    ep_rew_mean     | 205      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 52       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 3545     |
# | train/             |          |
# |    actor_loss      | 190      |
# |    critic_loss     | 1.96e+04 |
# |    ent_coef        | 3        |
# |    ent_coef_loss   | -12.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3444     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.1     |
# |    ep_rew_mean     | 205      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 52       |
# |    time_elapsed    | 68       |
# |    total_timesteps | 3599     |
# | train/             |          |
# |    actor_loss      | 177      |
# |    critic_loss     | 4.93e+04 |
# |    ent_coef        | 3.03     |
# |    ent_coef_loss   | -11.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3498     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.1     |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 52       |
# |    time_elapsed    | 69       |
# |    total_timesteps | 3659     |
# | train/             |          |
# |    actor_loss      | 177      |
# |    critic_loss     | 3.74e+04 |
# |    ent_coef        | 3.07     |
# |    ent_coef_loss   | -11.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3558     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.4     |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 52       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 3733     |
# | train/             |          |
# |    actor_loss      | 177      |
# |    critic_loss     | 3.86e+04 |
# |    ent_coef        | 3.12     |
# |    ent_coef_loss   | -11.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3632     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.5     |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 52       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 3803     |
# | train/             |          |
# |    actor_loss      | 186      |
# |    critic_loss     | 1.32e+04 |
# |    ent_coef        | 3.16     |
# |    ent_coef_loss   | -12.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3702     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.7     |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 52       |
# |    time_elapsed    | 74       |
# |    total_timesteps | 3875     |
# | train/             |          |
# |    actor_loss      | 227      |
# |    critic_loss     | 1.79e+04 |
# |    ent_coef        | 3.21     |
# |    ent_coef_loss   | -18.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3774     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.9     |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 52       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 3940     |
# | train/             |          |
# |    actor_loss      | 186      |
# |    critic_loss     | 4.78e+04 |
# |    ent_coef        | 3.27     |
# |    ent_coef_loss   | -14.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3839     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.2     |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 51       |
# |    time_elapsed    | 77       |
# |    total_timesteps | 4013     |
# | train/             |          |
# |    actor_loss      | 232      |
# |    critic_loss     | 2.02e+04 |
# |    ent_coef        | 3.33     |
# |    ent_coef_loss   | -15.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3912     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18       |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 51       |
# |    time_elapsed    | 78       |
# |    total_timesteps | 4061     |
# | train/             |          |
# |    actor_loss      | 229      |
# |    critic_loss     | 1.75e+04 |
# |    ent_coef        | 3.37     |
# |    ent_coef_loss   | -16.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3960     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.6     |
# |    ep_rew_mean     | 50.9     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 51       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 4116     |
# | train/             |          |
# |    actor_loss      | 228      |
# |    critic_loss     | 1.9e+04  |
# |    ent_coef        | 3.42     |
# |    ent_coef_loss   | -15.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4015     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.1     |
# |    ep_rew_mean     | 49       |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 51       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 4173     |
# | train/             |          |
# |    actor_loss      | 305      |
# |    critic_loss     | 2.74e+04 |
# |    ent_coef        | 3.47     |
# |    ent_coef_loss   | -17      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4072     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.1     |
# |    ep_rew_mean     | 47.7     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 51       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 4227     |
# | train/             |          |
# |    actor_loss      | 199      |
# |    critic_loss     | 4.1e+04  |
# |    ent_coef        | 3.52     |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4126     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.9     |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 51       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 4283     |
# | train/             |          |
# |    actor_loss      | 240      |
# |    critic_loss     | 2.26e+04 |
# |    ent_coef        | 3.57     |
# |    ent_coef_loss   | -15.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4182     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.6     |
# |    ep_rew_mean     | 45.3     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 51       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 4327     |
# | train/             |          |
# |    actor_loss      | 222      |
# |    critic_loss     | 2.81e+04 |
# |    ent_coef        | 3.61     |
# |    ent_coef_loss   | -15.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4226     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.6     |
# |    ep_rew_mean     | 44.3     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 51       |
# |    time_elapsed    | 85       |
# |    total_timesteps | 4382     |
# | train/             |          |
# |    actor_loss      | 233      |
# |    critic_loss     | 2.09e+04 |
# |    ent_coef        | 3.66     |
# |    ent_coef_loss   | -16.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4281     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.1     |
# |    ep_rew_mean     | 41.4     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 51       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 4434     |
# | train/             |          |
# |    actor_loss      | 266      |
# |    critic_loss     | 3.01e+04 |
# |    ent_coef        | 3.72     |
# |    ent_coef_loss   | -17      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4333     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 39.7     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 50       |
# |    time_elapsed    | 88       |
# |    total_timesteps | 4487     |
# | train/             |          |
# |    actor_loss      | 246      |
# |    critic_loss     | 1.08e+05 |
# |    ent_coef        | 3.77     |
# |    ent_coef_loss   | -16.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4386     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.1     |
# |    ep_rew_mean     | 37.9     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 50       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 4571     |
# | train/             |          |
# |    actor_loss      | 207      |
# |    critic_loss     | 9.45e+03 |
# |    ent_coef        | 3.86     |
# |    ent_coef_loss   | -16.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4470     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.2     |
# |    ep_rew_mean     | 36.8     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 50       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 4630     |
# | train/             |          |
# |    actor_loss      | 249      |
# |    critic_loss     | 3.43e+04 |
# |    ent_coef        | 3.92     |
# |    ent_coef_loss   | -17.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4529     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.7     |
# |    ep_rew_mean     | 34.9     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 50       |
# |    time_elapsed    | 92       |
# |    total_timesteps | 4677     |
# | train/             |          |
# |    actor_loss      | 261      |
# |    critic_loss     | 3.38e+04 |
# |    ent_coef        | 3.97     |
# |    ent_coef_loss   | -18.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4576     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.3     |
# |    ep_rew_mean     | 30.1     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 50       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 4742     |
# | train/             |          |
# |    actor_loss      | 257      |
# |    critic_loss     | 3.39e+04 |
# |    ent_coef        | 4.04     |
# |    ent_coef_loss   | -17.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4641     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.2     |
# |    ep_rew_mean     | 26.7     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 50       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 4786     |
# | train/             |          |
# |    actor_loss      | 250      |
# |    critic_loss     | 3.42e+04 |
# |    ent_coef        | 4.09     |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4685     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.1     |
# |    ep_rew_mean     | 26.1     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 50       |
# |    time_elapsed    | 96       |
# |    total_timesteps | 4835     |
# | train/             |          |
# |    actor_loss      | 377      |
# |    critic_loss     | 2.13e+04 |
# |    ent_coef        | 4.15     |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4734     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.2     |
# |    ep_rew_mean     | 25.9     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 50       |
# |    time_elapsed    | 97       |
# |    total_timesteps | 4897     |
# | train/             |          |
# |    actor_loss      | 271      |
# |    critic_loss     | 2.05e+04 |
# |    ent_coef        | 4.22     |
# |    ent_coef_loss   | -17.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4796     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.1     |
# |    ep_rew_mean     | 21.7     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 50       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 4956     |
# | train/             |          |
# |    actor_loss      | 281      |
# |    critic_loss     | 4.31e+03 |
# |    ent_coef        | 4.29     |
# |    ent_coef_loss   | -18.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4855     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.8     |
# |    ep_rew_mean     | 19.5     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 50       |
# |    time_elapsed    | 100      |
# |    total_timesteps | 5020     |
# | train/             |          |
# |    actor_loss      | 298      |
# |    critic_loss     | 4.37e+03 |
# |    ent_coef        | 4.37     |
# |    ent_coef_loss   | -18.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4919     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.7     |
# |    ep_rew_mean     | 18.6     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 50       |
# |    time_elapsed    | 100      |
# |    total_timesteps | 5064     |
# | train/             |          |
# |    actor_loss      | 286      |
# |    critic_loss     | 3.54e+04 |
# |    ent_coef        | 4.42     |
# |    ent_coef_loss   | -18.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4963     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.7     |
# |    ep_rew_mean     | 16.9     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 50       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 5128     |
# | train/             |          |
# |    actor_loss      | 306      |
# |    critic_loss     | 9.2e+03  |
# |    ent_coef        | 4.5      |
# |    ent_coef_loss   | -19.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5027     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.5     |
# |    ep_rew_mean     | 15.7     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 50       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 5181     |
# | train/             |          |
# |    actor_loss      | 303      |
# |    critic_loss     | 5.12e+03 |
# |    ent_coef        | 4.57     |
# |    ent_coef_loss   | -18.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5080     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.3     |
# |    ep_rew_mean     | 14.4     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 50       |
# |    time_elapsed    | 104      |
# |    total_timesteps | 5233     |
# | train/             |          |
# |    actor_loss      | 311      |
# |    critic_loss     | 1.95e+04 |
# |    ent_coef        | 4.64     |
# |    ent_coef_loss   | -18.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5132     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.1     |
# |    ep_rew_mean     | 12.3     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 50       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 5283     |
# | train/             |          |
# |    actor_loss      | 313      |
# |    critic_loss     | 1.3e+04  |
# |    ent_coef        | 4.71     |
# |    ent_coef_loss   | -19.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5182     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.1     |
# |    ep_rew_mean     | 12.3     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 50       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 5347     |
# | train/             |          |
# |    actor_loss      | 348      |
# |    critic_loss     | 2.13e+04 |
# |    ent_coef        | 4.79     |
# |    ent_coef_loss   | -20.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5246     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.8     |
# |    ep_rew_mean     | 12.1     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 50       |
# |    time_elapsed    | 107      |
# |    total_timesteps | 5397     |
# | train/             |          |
# |    actor_loss      | 350      |
# |    critic_loss     | 2.09e+04 |
# |    ent_coef        | 4.86     |
# |    ent_coef_loss   | -21.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5296     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.9     |
# |    ep_rew_mean     | 12.1     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 50       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 5453     |
# | train/             |          |
# |    actor_loss      | 341      |
# |    critic_loss     | 5.8e+03  |
# |    ent_coef        | 4.94     |
# |    ent_coef_loss   | -20.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14       |
# |    ep_rew_mean     | 12.2     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 50       |
# |    time_elapsed    | 110      |
# |    total_timesteps | 5516     |
# | train/             |          |
# |    actor_loss      | 372      |
# |    critic_loss     | 1.17e+06 |
# |    ent_coef        | 5.03     |
# |    ent_coef_loss   | -20.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5415     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14       |
# |    ep_rew_mean     | 12.3     |
# | time/              |          |
# ...
# |    fps             | 49       |
# |    time_elapsed    | 154      |
# |    total_timesteps | 7673     |
# | train/             |          |
# |    actor_loss      | 501      |
# |    critic_loss     | 2.48e+04 |
# |    ent_coef        | 8.43     |
# |    ent_coef_loss   | -15.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7572     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.4     |
# |    ep_rew_mean     | 199      |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 49       |
# |    time_elapsed    | 156      |
# |    total_timesteps | 7750     |
# | train/             |          |
# |    actor_loss      | 477      |
# |    critic_loss     | 4.58e+04 |
# |    ent_coef        | 8.58     |
# |    ent_coef_loss   | -14.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7649     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.9     |
# |    ep_rew_mean     | 202      |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 49       |
# |    time_elapsed    | 158      |
# |    total_timesteps | 7851     |
# | train/             |          |
# |    actor_loss      | 511      |
# |    critic_loss     | 1.44e+04 |
# |    ent_coef        | 8.8      |
# |    ent_coef_loss   | -16.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7750     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 49       |
# |    time_elapsed    | 159      |
# |    total_timesteps | 7945     |
# | train/             |          |
# |    actor_loss      | 814      |
# |    critic_loss     | 1.21e+06 |
# |    ent_coef        | 9.01     |
# |    ent_coef_loss   | -13.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7844     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | 206      |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 49       |
# |    time_elapsed    | 161      |
# |    total_timesteps | 8020     |
# | train/             |          |
# |    actor_loss      | 762      |
# |    critic_loss     | 3.29e+05 |
# |    ent_coef        | 9.18     |
# |    ent_coef_loss   | -15.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7919     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 208      |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 49       |
# |    time_elapsed    | 163      |
# |    total_timesteps | 8114     |
# | train/             |          |
# |    actor_loss      | 501      |
# |    critic_loss     | 1.23e+04 |
# |    ent_coef        | 9.41     |
# |    ent_coef_loss   | -16.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8013     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 49       |
# |    time_elapsed    | 165      |
# |    total_timesteps | 8190     |
# | train/             |          |
# |    actor_loss      | 556      |
# |    critic_loss     | 2.6e+04  |
# |    ent_coef        | 9.59     |
# |    ent_coef_loss   | -16.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8089     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 49       |
# |    time_elapsed    | 166      |
# |    total_timesteps | 8255     |
# | train/             |          |
# |    actor_loss      | 561      |
# |    critic_loss     | 1.41e+04 |
# |    ent_coef        | 9.75     |
# |    ent_coef_loss   | -19.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8154     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | 211      |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 49       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 8331     |
# | train/             |          |
# |    actor_loss      | 534      |
# |    critic_loss     | 2.65e+04 |
# |    ent_coef        | 9.95     |
# |    ent_coef_loss   | -16.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8230     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 215      |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 49       |
# |    time_elapsed    | 169      |
# |    total_timesteps | 8412     |
# | train/             |          |
# |    actor_loss      | 578      |
# |    critic_loss     | 2.77e+04 |
# |    ent_coef        | 10.2     |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8311     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 49       |
# |    time_elapsed    | 171      |
# |    total_timesteps | 8486     |
# | train/             |          |
# |    actor_loss      | 594      |
# |    critic_loss     | 1.1e+04  |
# |    ent_coef        | 10.4     |
# |    ent_coef_loss   | -18.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8385     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.8     |
# |    ep_rew_mean     | 208      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 49       |
# |    time_elapsed    | 172      |
# |    total_timesteps | 8571     |
# | train/             |          |
# |    actor_loss      | 615      |
# |    critic_loss     | 2.65e+04 |
# |    ent_coef        | 10.6     |
# |    ent_coef_loss   | -18      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8470     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 208      |
# | time/              |          |
# |    episodes        | 504      |
# |    fps             | 49       |
# |    time_elapsed    | 175      |
# |    total_timesteps | 8697     |
# | train/             |          |
# |    actor_loss      | 610      |
# |    critic_loss     | 4.6e+04  |
# |    ent_coef        | 11       |
# |    ent_coef_loss   | -17.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8596     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    episodes        | 508      |
# |    fps             | 49       |
# |    time_elapsed    | 177      |
# |    total_timesteps | 8803     |
# | train/             |          |
# |    actor_loss      | 597      |
# |    critic_loss     | 1.49e+04 |
# |    ent_coef        | 11.3     |
# |    ent_coef_loss   | -17.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8702     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 512      |
# |    fps             | 49       |
# |    time_elapsed    | 179      |
# |    total_timesteps | 8880     |
# | train/             |          |
# |    actor_loss      | 659      |
# |    critic_loss     | 3.64e+04 |
# |    ent_coef        | 11.5     |
# |    ent_coef_loss   | -14.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8779     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 516      |
# |    fps             | 49       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 8943     |
# | train/             |          |
# |    actor_loss      | 633      |
# |    critic_loss     | 1.28e+04 |
# |    ent_coef        | 11.7     |
# |    ent_coef_loss   | -15.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8842     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 49       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 9023     |
# | train/             |          |
# |    actor_loss      | 672      |
# |    critic_loss     | 2.33e+04 |
# |    ent_coef        | 12       |
# |    ent_coef_loss   | -15.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8922     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 214      |
# | time/              |          |
# |    episodes        | 524      |
# |    fps             | 49       |
# |    time_elapsed    | 183      |
# |    total_timesteps | 9094     |
# | train/             |          |
# |    actor_loss      | 727      |
# |    critic_loss     | 3.08e+04 |
# |    ent_coef        | 12.2     |
# |    ent_coef_loss   | -21.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8993     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 213      |
# | time/              |          |
# |    episodes        | 528      |
# |    fps             | 49       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 9205     |
# | train/             |          |
# |    actor_loss      | 708      |
# |    critic_loss     | 2.81e+04 |
# |    ent_coef        | 12.6     |
# |    ent_coef_loss   | -19.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9104     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 532      |
# |    fps             | 49       |
# |    time_elapsed    | 187      |
# |    total_timesteps | 9287     |
# | train/             |          |
# |    actor_loss      | 739      |
# |    critic_loss     | 4.63e+04 |
# |    ent_coef        | 12.9     |
# |    ent_coef_loss   | -19.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9186     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 72.1     |
# | time/              |          |
# |    episodes        | 536      |
# |    fps             | 49       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 9354     |
# | train/             |          |
# |    actor_loss      | 738      |
# |    critic_loss     | 2.13e+04 |
# |    ent_coef        | 13.2     |
# |    ent_coef_loss   | -18.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9253     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 74.3     |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 49       |
# |    time_elapsed    | 190      |
# |    total_timesteps | 9439     |
# | train/             |          |
# |    actor_loss      | 749      |
# |    critic_loss     | 2.32e+04 |
# |    ent_coef        | 13.5     |
# |    ent_coef_loss   | -18.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9338     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 74.3     |
# | time/              |          |
# |    episodes        | 544      |
# |    fps             | 49       |
# |    time_elapsed    | 191      |
# |    total_timesteps | 9510     |
# | train/             |          |
# |    actor_loss      | 781      |
# |    critic_loss     | 3.76e+04 |
# |    ent_coef        | 13.8     |
# |    ent_coef_loss   | -18.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9409     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | 77.7     |
# | time/              |          |
# |    episodes        | 548      |
# |    fps             | 49       |
# |    time_elapsed    | 193      |
# |    total_timesteps | 9592     |
# | train/             |          |
# |    actor_loss      | 786      |
# |    critic_loss     | 3.73e+04 |
# |    ent_coef        | 14.1     |
# |    ent_coef_loss   | -18.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9491     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 77.9     |
# | time/              |          |
# |    episodes        | 552      |
# |    fps             | 49       |
# |    time_elapsed    | 194      |
# |    total_timesteps | 9671     |
# | train/             |          |
# |    actor_loss      | 818      |
# |    critic_loss     | 2.76e+04 |
# |    ent_coef        | 14.4     |
# |    ent_coef_loss   | -17.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9570     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 80.4     |
# | time/              |          |
# |    episodes        | 556      |
# |    fps             | 49       |
# |    time_elapsed    | 197      |
# |    total_timesteps | 9771     |
# | train/             |          |
# |    actor_loss      | 812      |
# |    critic_loss     | 2.76e+04 |
# |    ent_coef        | 14.8     |
# |    ent_coef_loss   | -17.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9670     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 80.8     |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 49       |
# |    time_elapsed    | 198      |
# |    total_timesteps | 9858     |
# | train/             |          |
# |    actor_loss      | 894      |
# |    critic_loss     | 2.9e+04  |
# |    ent_coef        | 15.2     |
# |    ent_coef_loss   | -21.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9757     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 79.5     |
# | time/              |          |
# |    episodes        | 564      |
# |    fps             | 49       |
# |    time_elapsed    | 200      |
# |    total_timesteps | 9955     |
# | train/             |          |
# |    actor_loss      | 868      |
# |    critic_loss     | 1.19e+05 |
# |    ent_coef        | 15.7     |
# |    ent_coef_loss   | -18.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9854     |
# ---------------------------------

# %%
import pandas as pd

obs, info = env.reset()
terminated = False
truncated = False

data_array = []
while not (terminated or truncated):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    data_added = {**info, "reward": reward, "action": action}
    data_array.append(data_added)

df = pd.DataFrame.from_dict(data_array)
display(df)
# Out:
#     F        CR        MG  best_solution  percent_convergence   std_pop  \
# 0   1  0.000010  0.000000      65.009194             0.000000  3.187443
# 1   1  1.000000  0.089640      59.182610             0.000000  2.087413
# 2   1  1.000000  0.286830      57.779931             0.000000  1.552883
# 3   1  1.000000  0.303652      53.288030             0.000000  1.233303
# 4   1  0.645493  0.325068      51.296261             0.000000  0.983509
# 5   1  0.266923  0.357058      51.296261            64.496231  1.169637
# 6   1  1.000000  0.036587      51.296261            58.669647  0.000000
# 7   1  1.000000  0.052877      51.296261            57.266968  0.000000
# 8   1  0.715479  0.050717      51.296261            52.775068  0.000000
# 9   1  0.284146  0.063968      51.296261            50.783298  0.000000
# 10  1  0.202166  0.069074      50.644412            50.789816  0.282259
# 11  1  0.204753  0.060496      50.644412            50.789816  0.282259
# 12  1  0.192778  0.056410      50.644412            50.789816  0.282259
# 13  1  0.183936  0.053848      50.644412            50.789816  0.282259
# 14  1  0.172991  0.051845      50.644412            50.789816  0.282259
# 15  1  0.161291  0.050210      50.644412            50.137967  0.282259
# 16  1  0.150929  0.052368      50.644412            50.137967  0.282259
# 17  1  0.136319  0.054480      50.644412            50.137967  0.282259
# 18  1  0.120034  0.057758      50.644412            50.137967  0.282259
# 19  1  0.107916  0.060767      50.644412            50.137967  0.282259
# 20  1  0.096545  0.062054      50.644412            50.137967  0.282259
#
#     total_iteration  idx_iteration  patience_remaining     reward  \
# 0                20             19                 181   0.768687
# 1                40             39                 200   7.218835
# 2                60             59                 187   2.885968
# 3                80             79                 181   2.417665
# 4               100             99                 196   9.755557
# 5               120            119                 176  14.209785
# 6               140            139                 156  14.209785
# 7               160            159                 136  14.209785
# 8               180            179                 116  14.209785
# 9               200            199                  96  14.209785
# 10              220            219                 185  14.861634
# 11              240            239                 165   7.376865
# 12              260            259                 145   7.376865
# 13              280            279                 125   7.376865
# 14              300            299                 105   7.376865
# 15              320            319                  85   7.376865
# 16              340            339                  65   7.376865
# 17              360            359                  45   7.376865
# 18              380            379                  25   7.376865
# 19              400            399                   5   7.376865
# 20              420            419                 -15   7.376865
#
#                                   action
# 0                        [5.0, 0.0, 0.0]
# 1      [2.2632973, 4.993247, 0.08964017]
# 2      [2.3854535, 3.5444589, 0.2868302]
# 3       [1.984407, 1.4513268, 0.3036524]
# 4       [1.7184556, 0.645493, 0.3250683]
# 5       [1.3517275, 0.266923, 0.3570575]
# 6     [1.9835918, 2.7808032, 0.03658694]
# 7     [1.9136578, 1.354563, 0.052877367]
# 8     [1.7932026, 0.7154788, 0.05071652]
# 9   [1.5706172, 0.28414592, 0.063967735]
# 10   [1.4142475, 0.20216629, 0.06907368]
# 11  [1.3570178, 0.20475283, 0.060495943]
# 12  [1.3120091, 0.19277811, 0.056410015]
# 13   [1.2849424, 0.18393576, 0.05384794]
# 14  [1.2617371, 0.17299116, 0.051845104]
# 15  [1.2376578, 0.16129106, 0.050210178]
# 16   [1.179738, 0.15092939, 0.052367955]
# 17   [1.1658576, 0.1363194, 0.054480225]
# 18   [1.1745034, 0.12003392, 0.05775845]
# 19  [1.1875886, 0.10791555, 0.060766935]
# 20   [1.1788454, 0.09654477, 0.06205383]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, figsize=(10, 5))
x = np.arange(vrptw.idx_iteration + 1)
y1 = vrptw.global_solution_history
y2 = vrptw.fitness_trial_history
ax.plot(x, y1, marker=".", label="Best Solution")
ax.plot(x, y2, marker=".", label="Fitness Trial")
ax.set(
    xlabel="iteration",
    ylabel="Total Distance (Km.)",
    title="Differential Evoluation + Island Model Algorithm Replication",
)
ax.legend()
plt.show()
