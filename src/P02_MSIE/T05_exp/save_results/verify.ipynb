# %%
import pickle

import matplotlib.pyplot as plt
import numpy as np

from P02_MSIE.T05_exp.problem_sets import load_vrp
from P02_MSIE.T05_exp.env_v3 import AIMH_ENV

# %%
with open("vrp_20251112_212330_R2_seed42.pkl", "rb") as f:
    vrptw = pickle.load(f)

# %%
y = np.array(vrptw.global_solution_history) * vrptw.solution_scale_factor
x = np.arange(len(y))
plt.plot(x,y)
plt.xlabel("Iteration")
plt.ylabel("Total Distance (Km.)")
plt.title(f"Best Solution: {y.min():.2f}")
plt.show()

# %%
idx_best = vrptw.current_cost.argmin()
population = vrptw.population[idx_best, :]
print("Best solution route:", population)
# Out:
# Best solution route: [ 0.63823512  0.61735425  0.40491081 -0.13266661  0.96164049 -0.82389437
#   1.21938007 -0.86371343  0.7101145   0.4071643   0.64938058  0.54418012
#   0.05753585  0.49715382  0.33304796  0.49607548  0.1691039   0.32862197
#   1.36463504  0.74275171  0.81158443  0.80779757  1.62752415  0.47897556
#   0.76916987  0.53440626  0.96001188  1.63807486  0.85394846  0.19861384
#   0.36579417  0.22656481 -0.01009361  1.27593555  0.0318848  -0.28636955
#   0.27846842  0.19987297  0.72312721  0.79794319  0.56312659  0.00577066
#   0.42932277  0.40788493 -0.03405703  0.56918736  0.92250458  0.28739765
#   0.99639499 -0.1842931 ]

# %%
obj_func_calc = vrptw.objective_func(population)
obj_func_store1 = vrptw.current_cost[idx_best]
obj_func_store2 = vrptw.global_solution_history[-1] * vrptw.solution_scale_factor

print("Objective function calculated:", obj_func_calc)
print("Objective function stored (best):", obj_func_store1)
print("Objective function stored (global):", obj_func_store2)
# Out:
# Objective function calculated: 423.24258407802654
# Objective function stored (best): 423.24258407802654
# Objective function stored (global): 423.24258407802654
