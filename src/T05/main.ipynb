# %%
import pandas as pd
import pickle
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from vrp import VRP
import matplotlib.pyplot as plt
import seaborn as sns

# %%
skip_training = False
filename = "pi_star_v2.pkl"
max_current_iteration = 1000

# %%
class MetaEnv(gym.Env):
    def __init__(self, vrp):
        self.vrp = vrp

        self.nbin_obj = 30
        self.nbin_F = 20
        self.nbin_it = 3
        self.nA = 3
        self.nS = self.nbin_obj * self.nbin_F * self.nbin_it

        self.obj_bin = np.linspace(20, 40, self.nbin_obj)
        self.F_bin = np.linspace(0, 1, self.nbin_F)
        self.it_bin = np.linspace(0, 200, self.nbin_it).astype(int)

        self.observation_space = spaces.Dict(
            {
                "objective": spaces.Discrete(self.nbin_obj),
                "muation_rate": spaces.Discrete(self.nbin_F),
                "current_iteration": spaces.Discrete(self.nbin_it),
            }
        )

        self.action_space = spaces.Dict(
            {
                "mode": spaces.Discrete(3),
            }
        )

    def _print_bin(self):
        print(self.obj_bin)
        print(self.F_bin)
        print(self.it_bin)

    def _get_obs(self):
        """Convert internal state to observation format.

        Returns:
            dict: Observation
        """
        return {
            "objective": self._cb(
                np.digitize(self.vrp.get_best_solution(), self.obj_bin), self.nbin_obj
            ),
            "mutation_rate": self._cb(np.digitize(self.vrp.F, self.F_bin), self.nbin_F),
            "current_iteration": self._cb(
                np.digitize(self.vrp.current_iteration, self.it_bin), self.nbin_it
            ),
        }

    def _cb(self, idx, nbin):
        # Prevent the out-of-bound idx from np.digitize
        if idx >= nbin:
            return nbin - 1
        else:
            return idx

    def convert_to_flat_index(self, multi_index):
        return np.ravel_multi_index(
            multi_index=multi_index, dims=(self.nbin_obj, self.nbin_F, self.nbin_it)
        )

    def convert_to_multi_index(self, indices):
        return np.unravel_index(
            indices=indices, shape=(self.nbin_obj, self.nbin_F, self.nbin_it)
        )

    def _get_info(self):
        """Compute auxiliary information for debugging.

        Returns:
            dict: Info with distance between agent and target
        """
        return {
            "objective": self.vrp.get_best_solution(),
            "mutation_rate": self.vrp.F,
            "current_iteration": self.vrp.current_iteration,
            "delta_F": self.vrp.delta_F,
        }

    def reset(self, seed=None):
        self.vrp.reset()
        super().reset(seed=seed)
        observation = self._get_obs()
        info = self._get_info()
        return observation, info

    def step(self, action):
        if action == 1:
            self.vrp.change_F("DECREASE")
        elif action == 2:
            self.vrp.change_F("INCREASE")

        self.vrp.evolve(n_iteration=10)

        reward = -self.vrp.get_best_solution()
        if self.vrp.is_exceed_max_iteration():
            terminated = True
            truncated = True
        else:
            terminated = False
            truncated = False
        observation = self._get_obs()
        info = self._get_info()
        return observation, reward, terminated, truncated, info

# %%
flat_index = np.ravel_multi_index((1, 1, 1), (10, 10, 10))
flat_index
# Out:
# np.int64(111)

# %%
# nbin_obj = 10
# nbin_F = 11
# nbin_it = 1

# obj_bin = np.linspace(20, 40, nbin_obj)
# F_bin = np.linspace(0, 1, nbin_F)
# it_bin = np.linspace(0, 1000, nbin_it).astype(int)

# print(F_bin)
# print(it_bin)
# pi = np.zeros((nbin_obj, nbin_F, nbin_it))

# np.digitize(-1, it_bin)

# %%
# Distance matrix 50 node
df_distance = pd.read_excel("../Source/VRP_50_node.xlsx", sheet_name="Sheet1")
distance = df_distance.iloc[:,1:].to_numpy()

# %%
dimensions = len(distance) - 1
maxiters = 100
population_size = 100
bounds = np.array([[0, 1]] * dimensions)
Mutation_rate = np.array([0.5, 0.9])
Crossover_rate = np.array([0.1, 0.5])


vrp = VRP(
    population_size=population_size,
    dimensions=dimensions,
    bounds=bounds,
    Mutation_rate=Mutation_rate,
    Crossover_rate=Crossover_rate,
    distance=distance,
    max_iteration=max_current_iteration,
)

# %%
from gymnasium.utils.env_checker import check_env

env = MetaEnv(vrp=vrp)

# This will catch many common issues
try:
    check_env(env)
    print("Environment passes all checks!")
except Exception as e:
    print(f"Environment has issues: {e}")
# Out:
# Environment has issues: The first element returned by `env.reset()` is not within the observation space.

# %%
env = MetaEnv(vrp=vrp)

print(env.reset())
print(env.action_space.sample())
# Out:
# ({'objective': 29, 'mutation_rate': np.int64(10), 'current_iteration': np.int64(1)}, {'objective': np.float64(4741.831), 'mutation_rate': np.float64(0.5), 'current_iteration': 0, 'delta_F': 0.1})
# {'mode': np.int64(0)}

# %%
env.step(action=1)
# Out:
# ({'objective': 29,
#   'mutation_rate': np.int64(8),
#   'current_iteration': np.int64(1)},
#  np.float64(-4190.954000000001),
#  False,
#  False,
#  {'objective': np.float64(4190.954000000001),
#   'mutation_rate': np.float64(0.4),
#   'current_iteration': 10,
#   'delta_F': 0.1})

# %%
env._print_bin()
# Out:
# [20.         20.68965517 21.37931034 22.06896552 22.75862069 23.44827586
#  24.13793103 24.82758621 25.51724138 26.20689655 26.89655172 27.5862069
#  28.27586207 28.96551724 29.65517241 30.34482759 31.03448276 31.72413793
#  32.4137931  33.10344828 33.79310345 34.48275862 35.17241379 35.86206897
#  36.55172414 37.24137931 37.93103448 38.62068966 39.31034483 40.        ]
# [0.         0.05263158 0.10526316 0.15789474 0.21052632 0.26315789
#  0.31578947 0.36842105 0.42105263 0.47368421 0.52631579 0.57894737
#  0.63157895 0.68421053 0.73684211 0.78947368 0.84210526 0.89473684
#  0.94736842 1.        ]
# [  0 100 200]

# %%
# Greedy in the Limit with Infinite Exploration (GLIE)
def GLIE(env, discount_factor=1.0, episode_count=100):
    """
    Find optimal policy given an environment.

    Args:
        env: OpenAI env. In model free setup you have no access to env.P,
             transition dynamics of the environment.
             use step(a) to take an action and receive a tuple
             of (s', r, done, info)
             env.nS is number of states in the environment.
             env.nA is number of actions in the environment.
        episode_count: Number of episodes:
        discount_factor: Gamma discount factor.

    Returns:
        Vector of length env.nS representing the value function.
        policy:[S, A] shaped matrix representing the policy. Random in our case

    """
    # Start with (all 0) state value array and state-action matrix.
    # also initialize visit count to zero for the state-action visit count.
    V = np.zeros(env.nS)
    N = np.zeros((env.nS, env.nA))
    Q = np.zeros((env.nS, env.nA))
    # random policy
    policy = [np.random.randint(env.nA) for _ in range(env.nS)]
    k = 1
    eps = 1

    def argmax_a(arr):
        """
        Return idx of max element in an array.
        Break ties uniformly.
        """
        max_idx = []
        max_val = float("-inf")
        for idx, elem in enumerate(arr):
            if elem == max_val:
                max_idx.append(idx)
            elif elem > max_val:
                max_idx = [idx]
                max_val = elem
        return np.random.choice(max_idx)

    def get_action(state):
        if np.random.random() < eps:
            return np.random.choice(env.nA)
        else:
            return argmax_a(Q[state])

    # run multiple episodes
    while k <= episode_count:
        print(f"k={k}")
        # collect samples for one episode
        episode_states = []
        episode_actions = []
        episode_returns = []
        _state, _ = env.reset()
        state = env.convert_to_flat_index(
            (
                _state["objective"],
                _state["mutation_rate"],
                _state["current_iteration"],
            )
        )
        episode_states.append(state)
        while True:
            action = get_action(state)
            episode_actions.append(action)
            (_state, reward, done, _, info) = env.step(action)
            # print(info)
            state = env.convert_to_flat_index(
                (
                    _state["objective"],
                    _state["mutation_rate"],
                    _state["current_iteration"],
                )
            )
            episode_returns.append(reward)
            if not done:
                episode_states.append(state)
            else:
                break

        # update state-action values
        G = 0
        count = len(episode_states)
        for t in range(count - 1, -1, -1):
            s, a, r = episode_states[t], episode_actions[t], episode_returns[t]
            G = discount_factor * G + r
            N[s, a] += 1
            Q[s, a] = Q[s, a] + 1 / N[s, a] * (G - Q[s, a])

        # Update policy and optimal value
        k = k + 1
        eps = 1 / k
        # uncomment "if" to have higher exploration initially and
        # then let epislon decay after 5000 episodes
        # if k <=100:
        #    eps = 0.02

        for s in range(env.nS):
            best_action = argmax_a(Q[s])
            policy[s] = best_action
            V[s] = Q[s, best_action]

    return np.array(V), np.array(policy)

# %%
if not skip_training:
    # run mc policy control GLIE
    V_pi, policy = GLIE(env, discount_factor=1.0, episode_count=10)

    action_labels = {0: "NO", 1: "REDUCE", 2: "INCREASE"}
    # print policy
    optimal_actions = [action_labels[policy[s]] for s in range(env.nS)]

    with open(filename, "wb") as file:
        pickle.dump(
            dict(policy=policy, V_pi=V_pi, optimal_actions=optimal_actions), file
        )

else:
    with open(filename, "rb") as file:
        data = pickle.load(file)
        policy = data["policy"]
        V_pi = data["V_pi"]
        optimal_actions = data["optimal_actions"]
# Out:
# k=1
# k=2
# k=3
# k=4
# k=5
# k=6
# k=7
# k=8
# k=9
# k=10

# %%
plt.plot(V_pi)

# %%
sns.countplot(optimal_actions)
# Out:
# <Axes: xlabel='count'>

# %%
n_epi = 10
epi = []
for _ in range(n_epi):
    total_reward = 0.0
    total_steps = 0
    curState, _ = env.reset()
    reward_arr = []

    done = False
    while not done:
        action = np.random.randint(3)
        curState, reward, terminated, truncated, info = env.step(action)
        reward_arr.append(-reward)
        total_reward += reward
        total_steps += 1
        done = terminated or truncated
        print(
            f"Step {total_steps:2d}: action={action:2d}, Reward={reward:5.2f}, "
            f"Terminated={terminated}, Truncated={truncated}, info={info}"
        )

    print(
        f"Episode finished after {total_steps} steps with total reward: {total_reward:.2f}"
    )

    env.close()
    epi.append(reward_arr)
# Out:
# Step  1: action= 2, Reward=-4189.38, Terminated=False, Truncated=False, info={'objective': np.float64(4189.38), 'mutation_rate': np.float64(0.6), 'current_iteration': 10, 'delta_F': 0.1}
# Step  2: action= 0, Reward=-3956.23, Terminated=False, Truncated=False, info={'objective': np.float64(3956.2330000000015), 'mutation_rate': np.float64(0.6), 'current_iteration': 20, 'delta_F': 0.1}
# Step  3: action= 0, Reward=-3847.08, Terminated=False, Truncated=False, info={'objective': np.float64(3847.079999999999), 'mutation_rate': np.float64(0.6), 'current_iteration': 30, 'delta_F': 0.1}
# Step  4: action= 1, Reward=-3142.22, Terminated=False, Truncated=False, info={'objective': np.float64(3142.22), 'mutation_rate': np.float64(0.5), 'current_iteration': 40, 'delta_F': 0.1}
# Step  5: action= 1, Reward=-2816.04, Terminated=False, Truncated=False, info={'objective': np.float64(2816.044999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 50, 'delta_F': 0.1}
# Step  6: action= 1, Reward=-2816.04, Terminated=False, Truncated=False, info={'objective': np.float64(2816.044999999999), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 60, 'delta_F': 0.1}
# Step  7: action= 0, Reward=-2733.56, Terminated=False, Truncated=False, info={'objective': np.float64(2733.5640000000003), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 70, 'delta_F': 0.1}
# Step  8: action= 0, Reward=-2733.56, Terminated=False, Truncated=False, info={'objective': np.float64(2733.5640000000003), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 80, 'delta_F': 0.1}
# Step  9: action= 0, Reward=-2464.07, Terminated=False, Truncated=False, info={'objective': np.float64(2464.071), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 90, 'delta_F': 0.1}
# Step 10: action= 2, Reward=-2464.07, Terminated=False, Truncated=False, info={'objective': np.float64(2464.071), 'mutation_rate': np.float64(0.4), 'current_iteration': 100, 'delta_F': 0.1}
# Step 11: action= 0, Reward=-2464.07, Terminated=False, Truncated=False, info={'objective': np.float64(2464.071), 'mutation_rate': np.float64(0.4), 'current_iteration': 110, 'delta_F': 0.1}
# Step 12: action= 2, Reward=-2464.07, Terminated=False, Truncated=False, info={'objective': np.float64(2464.071), 'mutation_rate': np.float64(0.5), 'current_iteration': 120, 'delta_F': 0.1}
# Step 13: action= 1, Reward=-2464.07, Terminated=False, Truncated=False, info={'objective': np.float64(2464.071), 'mutation_rate': np.float64(0.4), 'current_iteration': 130, 'delta_F': 0.1}
# Step 14: action= 1, Reward=-2413.24, Terminated=False, Truncated=False, info={'objective': np.float64(2413.241), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 140, 'delta_F': 0.1}
# Step 15: action= 1, Reward=-2413.24, Terminated=False, Truncated=False, info={'objective': np.float64(2413.241), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 150, 'delta_F': 0.1}
# Step 16: action= 0, Reward=-2402.96, Terminated=False, Truncated=False, info={'objective': np.float64(2402.959999999999), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 160, 'delta_F': 0.1}
# Step 17: action= 0, Reward=-2351.43, Terminated=False, Truncated=False, info={'objective': np.float64(2351.4300000000003), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 170, 'delta_F': 0.1}
# Step 18: action= 1, Reward=-2351.43, Terminated=False, Truncated=False, info={'objective': np.float64(2351.4300000000003), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 180, 'delta_F': 0.1}
# Step 19: action= 1, Reward=-2345.23, Terminated=False, Truncated=False, info={'objective': np.float64(2345.226), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 190, 'delta_F': 0.1}
# Step 20: action= 1, Reward=-2345.23, Terminated=False, Truncated=False, info={'objective': np.float64(2345.226), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 200, 'delta_F': 0.1}
# Step 21: action= 2, Reward=-2314.47, Terminated=False, Truncated=False, info={'objective': np.float64(2314.4700000000003), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 210, 'delta_F': 0.1}
# Step 22: action= 0, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 220, 'delta_F': 0.1}
# Step 23: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 230, 'delta_F': 0.1}
# Step 24: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 240, 'delta_F': 0.1}
# Step 25: action= 0, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 250, 'delta_F': 0.1}
# Step 26: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.5), 'current_iteration': 260, 'delta_F': 0.1}
# Step 27: action= 1, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 270, 'delta_F': 0.1}
# Step 28: action= 0, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 280, 'delta_F': 0.1}
# Step 29: action= 0, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 290, 'delta_F': 0.1}
# Step 30: action= 1, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 300, 'delta_F': 0.1}
# Step 31: action= 0, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 310, 'delta_F': 0.1}
# Step 32: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 320, 'delta_F': 0.1}
# Step 33: action= 1, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 330, 'delta_F': 0.1}
# Step 34: action= 1, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 340, 'delta_F': 0.1}
# Step 35: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 350, 'delta_F': 0.1}
# Step 36: action= 0, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 360, 'delta_F': 0.1}
# Step 37: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 370, 'delta_F': 0.1}
# Step 38: action= 1, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 380, 'delta_F': 0.1}
# Step 39: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 390, 'delta_F': 0.1}
# Step 40: action= 0, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 400, 'delta_F': 0.1}
# Step 41: action= 0, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 410, 'delta_F': 0.1}
# Step 42: action= 0, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 420, 'delta_F': 0.1}
# Step 43: action= 1, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 430, 'delta_F': 0.1}
# Step 44: action= 1, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 440, 'delta_F': 0.1}
# Step 45: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 450, 'delta_F': 0.1}
# Step 46: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.4), 'current_iteration': 460, 'delta_F': 0.1}
# Step 47: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.5), 'current_iteration': 470, 'delta_F': 0.1}
# Step 48: action= 2, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.6), 'current_iteration': 480, 'delta_F': 0.1}
# Step 49: action= 1, Reward=-2306.03, Terminated=False, Truncated=False, info={'objective': np.float64(2306.025), 'mutation_rate': np.float64(0.5), 'current_iteration': 490, 'delta_F': 0.1}
# Step 50: action= 2, Reward=-2293.68, Terminated=False, Truncated=False, info={'objective': np.float64(2293.679), 'mutation_rate': np.float64(0.6), 'current_iteration': 500, 'delta_F': 0.1}
# Step 51: action= 2, Reward=-2293.68, Terminated=False, Truncated=False, info={'objective': np.float64(2293.679), 'mutation_rate': np.float64(0.7), 'current_iteration': 510, 'delta_F': 0.1}
# Step 52: action= 1, Reward=-2293.68, Terminated=False, Truncated=False, info={'objective': np.float64(2293.679), 'mutation_rate': np.float64(0.6), 'current_iteration': 520, 'delta_F': 0.1}
# Step 53: action= 0, Reward=-2293.68, Terminated=False, Truncated=False, info={'objective': np.float64(2293.679), 'mutation_rate': np.float64(0.6), 'current_iteration': 530, 'delta_F': 0.1}
# Step 54: action= 2, Reward=-2293.68, Terminated=False, Truncated=False, info={'objective': np.float64(2293.679), 'mutation_rate': np.float64(0.7), 'current_iteration': 540, 'delta_F': 0.1}
# Step 55: action= 2, Reward=-2293.68, Terminated=False, Truncated=False, info={'objective': np.float64(2293.679), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 550, 'delta_F': 0.1}
# Step 56: action= 0, Reward=-2293.68, Terminated=False, Truncated=False, info={'objective': np.float64(2293.679), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 560, 'delta_F': 0.1}
# Step 57: action= 2, Reward=-2293.68, Terminated=False, Truncated=False, info={'objective': np.float64(2293.679), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 570, 'delta_F': 0.1}
# Step 58: action= 2, Reward=-2293.68, Terminated=False, Truncated=False, info={'objective': np.float64(2293.679), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 580, 'delta_F': 0.1}
# Step 59: action= 1, Reward=-2279.85, Terminated=False, Truncated=False, info={'objective': np.float64(2279.8479999999995), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 590, 'delta_F': 0.1}
# Step 60: action= 1, Reward=-2260.27, Terminated=False, Truncated=False, info={'objective': np.float64(2260.266), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 600, 'delta_F': 0.1}
# Step 61: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 610, 'delta_F': 0.1}
# Step 62: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 620, 'delta_F': 0.1}
# Step 63: action= 1, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 630, 'delta_F': 0.1}
# Step 64: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 640, 'delta_F': 0.1}
# Step 65: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 650, 'delta_F': 0.1}
# Step 66: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 660, 'delta_F': 0.1}
# Step 67: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 670, 'delta_F': 0.1}
# Step 68: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 680, 'delta_F': 0.1}
# Step 69: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 690, 'delta_F': 0.1}
# Step 70: action= 1, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 700, 'delta_F': 0.1}
# Step 71: action= 1, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 710, 'delta_F': 0.1}
# Step 72: action= 1, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7), 'current_iteration': 720, 'delta_F': 0.1}
# Step 73: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 730, 'delta_F': 0.1}
# Step 74: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 740, 'delta_F': 0.1}
# Step 75: action= 1, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7), 'current_iteration': 750, 'delta_F': 0.1}
# Step 76: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7), 'current_iteration': 760, 'delta_F': 0.1}
# Step 77: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 770, 'delta_F': 0.1}
# Step 78: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 780, 'delta_F': 0.1}
# Step 79: action= 1, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7), 'current_iteration': 790, 'delta_F': 0.1}
# Step 80: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 800, 'delta_F': 0.1}
# Step 81: action= 1, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7), 'current_iteration': 810, 'delta_F': 0.1}
# Step 82: action= 1, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.6), 'current_iteration': 820, 'delta_F': 0.1}
# Step 83: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.6), 'current_iteration': 830, 'delta_F': 0.1}
# Step 84: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.6), 'current_iteration': 840, 'delta_F': 0.1}
# Step 85: action= 1, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.5), 'current_iteration': 850, 'delta_F': 0.1}
# Step 86: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.6), 'current_iteration': 860, 'delta_F': 0.1}
# Step 87: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7), 'current_iteration': 870, 'delta_F': 0.1}
# Step 88: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7), 'current_iteration': 880, 'delta_F': 0.1}
# Step 89: action= 0, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7), 'current_iteration': 890, 'delta_F': 0.1}
# Step 90: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 900, 'delta_F': 0.1}
# Step 91: action= 2, Reward=-2240.13, Terminated=False, Truncated=False, info={'objective': np.float64(2240.132), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 910, 'delta_F': 0.1}
# Step 92: action= 2, Reward=-2238.50, Terminated=False, Truncated=False, info={'objective': np.float64(2238.4980000000005), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 920, 'delta_F': 0.1}
# Step 93: action= 0, Reward=-2236.91, Terminated=False, Truncated=False, info={'objective': np.float64(2236.9110000000005), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 930, 'delta_F': 0.1}
# Step 94: action= 0, Reward=-2228.23, Terminated=False, Truncated=False, info={'objective': np.float64(2228.2290000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 940, 'delta_F': 0.1}
# Step 95: action= 0, Reward=-2228.23, Terminated=False, Truncated=False, info={'objective': np.float64(2228.2290000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 950, 'delta_F': 0.1}
# Step 96: action= 1, Reward=-2228.23, Terminated=False, Truncated=False, info={'objective': np.float64(2228.2290000000003), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 960, 'delta_F': 0.1}
# Step 97: action= 2, Reward=-2224.52, Terminated=False, Truncated=False, info={'objective': np.float64(2224.5170000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 970, 'delta_F': 0.1}
# Step 98: action= 2, Reward=-2224.52, Terminated=False, Truncated=False, info={'objective': np.float64(2224.5170000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 980, 'delta_F': 0.1}
# Step 99: action= 2, Reward=-2222.33, Terminated=False, Truncated=False, info={'objective': np.float64(2222.3340000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 990, 'delta_F': 0.1}
# Step 100: action= 1, Reward=-2222.33, Terminated=False, Truncated=False, info={'objective': np.float64(2222.3340000000003), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 1000, 'delta_F': 0.1}
# Step 101: action= 0, Reward=-2222.33, Terminated=True, Truncated=True, info={'objective': np.float64(2222.3340000000003), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 1010, 'delta_F': 0.1}
# Episode finished after 101 steps with total reward: -238963.86
# Step  1: action= 1, Reward=-3747.02, Terminated=False, Truncated=False, info={'objective': np.float64(3747.02), 'mutation_rate': np.float64(0.4), 'current_iteration': 10, 'delta_F': 0.1}
# Step  2: action= 1, Reward=-3747.02, Terminated=False, Truncated=False, info={'objective': np.float64(3747.02), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 20, 'delta_F': 0.1}
# Step  3: action= 1, Reward=-3747.02, Terminated=False, Truncated=False, info={'objective': np.float64(3747.02), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 30, 'delta_F': 0.1}
# Step  4: action= 2, Reward=-3445.36, Terminated=False, Truncated=False, info={'objective': np.float64(3445.355), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 40, 'delta_F': 0.1}
# Step  5: action= 1, Reward=-3445.36, Terminated=False, Truncated=False, info={'objective': np.float64(3445.355), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 50, 'delta_F': 0.1}
# Step  6: action= 1, Reward=-3445.36, Terminated=False, Truncated=False, info={'objective': np.float64(3445.355), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 60, 'delta_F': 0.1}
# Step  7: action= 1, Reward=-3431.56, Terminated=False, Truncated=False, info={'objective': np.float64(3431.5649999999987), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 70, 'delta_F': 0.1}
# Step  8: action= 2, Reward=-3431.56, Terminated=False, Truncated=False, info={'objective': np.float64(3431.5649999999987), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 80, 'delta_F': 0.1}
# Step  9: action= 1, Reward=-3215.75, Terminated=False, Truncated=False, info={'objective': np.float64(3215.7540000000004), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 90, 'delta_F': 0.1}
# Step 10: action= 2, Reward=-3215.75, Terminated=False, Truncated=False, info={'objective': np.float64(3215.7540000000004), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 100, 'delta_F': 0.1}
# Step 11: action= 1, Reward=-3121.57, Terminated=False, Truncated=False, info={'objective': np.float64(3121.5729999999994), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 110, 'delta_F': 0.1}
# Step 12: action= 0, Reward=-3121.57, Terminated=False, Truncated=False, info={'objective': np.float64(3121.5729999999994), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 120, 'delta_F': 0.1}
# Step 13: action= 1, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 130, 'delta_F': 0.1}
# Step 14: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 140, 'delta_F': 0.1}
# Step 15: action= 1, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 150, 'delta_F': 0.1}
# Step 16: action= 1, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 160, 'delta_F': 0.1}
# Step 17: action= 2, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 170, 'delta_F': 0.1}
# Step 18: action= 1, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 180, 'delta_F': 0.1}
# Step 19: action= 1, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 190, 'delta_F': 0.1}
# Step 20: action= 2, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 200, 'delta_F': 0.1}
# Step 21: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 210, 'delta_F': 0.1}
# Step 22: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 220, 'delta_F': 0.1}
# Step 23: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 230, 'delta_F': 0.1}
# Step 24: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 240, 'delta_F': 0.1}
# Step 25: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 250, 'delta_F': 0.1}
# Step 26: action= 1, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 260, 'delta_F': 0.1}
# Step 27: action= 2, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 270, 'delta_F': 0.1}
# Step 28: action= 1, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 280, 'delta_F': 0.1}
# Step 29: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 290, 'delta_F': 0.1}
# Step 30: action= 2, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 300, 'delta_F': 0.1}
# Step 31: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 310, 'delta_F': 0.1}
# Step 32: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 320, 'delta_F': 0.1}
# Step 33: action= 0, Reward=-3096.69, Terminated=False, Truncated=False, info={'objective': np.float64(3096.6939999999986), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 330, 'delta_F': 0.1}
# Step 34: action= 1, Reward=-3071.58, Terminated=False, Truncated=False, info={'objective': np.float64(3071.5789999999993), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 340, 'delta_F': 0.1}
# Step 35: action= 0, Reward=-2924.59, Terminated=False, Truncated=False, info={'objective': np.float64(2924.5939999999987), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 350, 'delta_F': 0.1}
# Step 36: action= 0, Reward=-2924.59, Terminated=False, Truncated=False, info={'objective': np.float64(2924.5939999999987), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 360, 'delta_F': 0.1}
# Step 37: action= 0, Reward=-2924.59, Terminated=False, Truncated=False, info={'objective': np.float64(2924.5939999999987), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 370, 'delta_F': 0.1}
# Step 38: action= 0, Reward=-2924.59, Terminated=False, Truncated=False, info={'objective': np.float64(2924.5939999999987), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 380, 'delta_F': 0.1}
# Step 39: action= 1, Reward=-2924.59, Terminated=False, Truncated=False, info={'objective': np.float64(2924.5939999999987), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 390, 'delta_F': 0.1}
# Step 40: action= 1, Reward=-2924.59, Terminated=False, Truncated=False, info={'objective': np.float64(2924.5939999999987), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 400, 'delta_F': 0.1}
# Step 41: action= 1, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 410, 'delta_F': 0.1}
# Step 42: action= 1, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 420, 'delta_F': 0.1}
# Step 43: action= 0, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 430, 'delta_F': 0.1}
# Step 44: action= 0, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 440, 'delta_F': 0.1}
# Step 45: action= 1, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 450, 'delta_F': 0.1}
# Step 46: action= 2, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 460, 'delta_F': 0.1}
# Step 47: action= 1, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 470, 'delta_F': 0.1}
# Step 48: action= 2, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 480, 'delta_F': 0.1}
# Step 49: action= 2, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 490, 'delta_F': 0.1}
# Step 50: action= 1, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 500, 'delta_F': 0.1}
# Step 51: action= 0, Reward=-2897.79, Terminated=False, Truncated=False, info={'objective': np.float64(2897.7880000000005), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 510, 'delta_F': 0.1}
# Step 52: action= 1, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 520, 'delta_F': 0.1}
# Step 53: action= 1, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 530, 'delta_F': 0.1}
# Step 54: action= 2, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 540, 'delta_F': 0.1}
# Step 55: action= 1, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 550, 'delta_F': 0.1}
# Step 56: action= 0, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 560, 'delta_F': 0.1}
# Step 57: action= 2, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 570, 'delta_F': 0.1}
# Step 58: action= 2, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 580, 'delta_F': 0.1}
# Step 59: action= 1, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 590, 'delta_F': 0.1}
# Step 60: action= 2, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 600, 'delta_F': 0.1}
# Step 61: action= 1, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 610, 'delta_F': 0.1}
# Step 62: action= 0, Reward=-2823.15, Terminated=False, Truncated=False, info={'objective': np.float64(2823.154999999999), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 620, 'delta_F': 0.1}
# Step 63: action= 1, Reward=-2787.15, Terminated=False, Truncated=False, info={'objective': np.float64(2787.151), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 630, 'delta_F': 0.1}
# Step 64: action= 2, Reward=-2787.15, Terminated=False, Truncated=False, info={'objective': np.float64(2787.151), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 640, 'delta_F': 0.1}
# Step 65: action= 1, Reward=-2771.27, Terminated=False, Truncated=False, info={'objective': np.float64(2771.2699999999995), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 650, 'delta_F': 0.1}
# Step 66: action= 1, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 660, 'delta_F': 0.1}
# Step 67: action= 2, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 670, 'delta_F': 0.1}
# Step 68: action= 0, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 680, 'delta_F': 0.1}
# Step 69: action= 0, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 690, 'delta_F': 0.1}
# Step 70: action= 2, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 700, 'delta_F': 0.1}
# Step 71: action= 2, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.4), 'current_iteration': 710, 'delta_F': 0.1}
# Step 72: action= 2, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.5), 'current_iteration': 720, 'delta_F': 0.1}
# Step 73: action= 1, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.4), 'current_iteration': 730, 'delta_F': 0.1}
# Step 74: action= 1, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 740, 'delta_F': 0.1}
# Step 75: action= 0, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 750, 'delta_F': 0.1}
# Step 76: action= 0, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 760, 'delta_F': 0.1}
# Step 77: action= 1, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 770, 'delta_F': 0.1}
# Step 78: action= 1, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 780, 'delta_F': 0.1}
# Step 79: action= 0, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 790, 'delta_F': 0.1}
# Step 80: action= 1, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 800, 'delta_F': 0.1}
# Step 81: action= 2, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 810, 'delta_F': 0.1}
# Step 82: action= 1, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 820, 'delta_F': 0.1}
# Step 83: action= 0, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 830, 'delta_F': 0.1}
# Step 84: action= 1, Reward=-2675.26, Terminated=False, Truncated=False, info={'objective': np.float64(2675.255), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 840, 'delta_F': 0.1}
# Step 85: action= 0, Reward=-2596.26, Terminated=False, Truncated=False, info={'objective': np.float64(2596.2590000000014), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 850, 'delta_F': 0.1}
# Step 86: action= 0, Reward=-2596.26, Terminated=False, Truncated=False, info={'objective': np.float64(2596.2590000000014), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 860, 'delta_F': 0.1}
# Step 87: action= 1, Reward=-2596.26, Terminated=False, Truncated=False, info={'objective': np.float64(2596.2590000000014), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 870, 'delta_F': 0.1}
# Step 88: action= 0, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 880, 'delta_F': 0.1}
# Step 89: action= 1, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 890, 'delta_F': 0.1}
# Step 90: action= 1, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 900, 'delta_F': 0.1}
# Step 91: action= 2, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 910, 'delta_F': 0.1}
# Step 92: action= 1, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 920, 'delta_F': 0.1}
# Step 93: action= 0, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 930, 'delta_F': 0.1}
# Step 94: action= 0, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 940, 'delta_F': 0.1}
# Step 95: action= 2, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 950, 'delta_F': 0.1}
# Step 96: action= 0, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 960, 'delta_F': 0.1}
# Step 97: action= 2, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 970, 'delta_F': 0.1}
# Step 98: action= 1, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 980, 'delta_F': 0.1}
# Step 99: action= 0, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 990, 'delta_F': 0.1}
# Step 100: action= 2, Reward=-2581.23, Terminated=False, Truncated=False, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 1000, 'delta_F': 0.1}
# Step 101: action= 0, Reward=-2581.23, Terminated=True, Truncated=True, info={'objective': np.float64(2581.2340000000004), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 1010, 'delta_F': 0.1}
# Episode finished after 101 steps with total reward: -292796.47
# Step  1: action= 2, Reward=-3882.61, Terminated=False, Truncated=False, info={'objective': np.float64(3882.607), 'mutation_rate': np.float64(0.6), 'current_iteration': 10, 'delta_F': 0.1}
# Step  2: action= 1, Reward=-3874.61, Terminated=False, Truncated=False, info={'objective': np.float64(3874.611000000001), 'mutation_rate': np.float64(0.5), 'current_iteration': 20, 'delta_F': 0.1}
# Step  3: action= 1, Reward=-3874.61, Terminated=False, Truncated=False, info={'objective': np.float64(3874.611000000001), 'mutation_rate': np.float64(0.4), 'current_iteration': 30, 'delta_F': 0.1}
# Step  4: action= 2, Reward=-3687.49, Terminated=False, Truncated=False, info={'objective': np.float64(3687.493), 'mutation_rate': np.float64(0.5), 'current_iteration': 40, 'delta_F': 0.1}
# Step  5: action= 1, Reward=-3687.49, Terminated=False, Truncated=False, info={'objective': np.float64(3687.493), 'mutation_rate': np.float64(0.4), 'current_iteration': 50, 'delta_F': 0.1}
# Step  6: action= 1, Reward=-3265.86, Terminated=False, Truncated=False, info={'objective': np.float64(3265.8620000000005), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 60, 'delta_F': 0.1}
# Step  7: action= 2, Reward=-3265.86, Terminated=False, Truncated=False, info={'objective': np.float64(3265.8620000000005), 'mutation_rate': np.float64(0.4), 'current_iteration': 70, 'delta_F': 0.1}
# Step  8: action= 0, Reward=-3083.71, Terminated=False, Truncated=False, info={'objective': np.float64(3083.7139999999995), 'mutation_rate': np.float64(0.4), 'current_iteration': 80, 'delta_F': 0.1}
# Step  9: action= 2, Reward=-3083.71, Terminated=False, Truncated=False, info={'objective': np.float64(3083.7139999999995), 'mutation_rate': np.float64(0.5), 'current_iteration': 90, 'delta_F': 0.1}
# Step 10: action= 2, Reward=-2948.61, Terminated=False, Truncated=False, info={'objective': np.float64(2948.6109999999994), 'mutation_rate': np.float64(0.6), 'current_iteration': 100, 'delta_F': 0.1}
# Step 11: action= 2, Reward=-2584.80, Terminated=False, Truncated=False, info={'objective': np.float64(2584.7979999999993), 'mutation_rate': np.float64(0.7), 'current_iteration': 110, 'delta_F': 0.1}
# Step 12: action= 2, Reward=-2563.55, Terminated=False, Truncated=False, info={'objective': np.float64(2563.5520000000006), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 120, 'delta_F': 0.1}
# Step 13: action= 2, Reward=-2501.70, Terminated=False, Truncated=False, info={'objective': np.float64(2501.6980000000003), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 130, 'delta_F': 0.1}
# Step 14: action= 0, Reward=-2486.22, Terminated=False, Truncated=False, info={'objective': np.float64(2486.224), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 140, 'delta_F': 0.1}
# Step 15: action= 1, Reward=-2486.22, Terminated=False, Truncated=False, info={'objective': np.float64(2486.224), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 150, 'delta_F': 0.1}
# Step 16: action= 0, Reward=-2486.22, Terminated=False, Truncated=False, info={'objective': np.float64(2486.224), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 160, 'delta_F': 0.1}
# Step 17: action= 1, Reward=-2481.54, Terminated=False, Truncated=False, info={'objective': np.float64(2481.536), 'mutation_rate': np.float64(0.7), 'current_iteration': 170, 'delta_F': 0.1}
# Step 18: action= 0, Reward=-2478.47, Terminated=False, Truncated=False, info={'objective': np.float64(2478.4700000000003), 'mutation_rate': np.float64(0.7), 'current_iteration': 180, 'delta_F': 0.1}
# Step 19: action= 0, Reward=-2478.47, Terminated=False, Truncated=False, info={'objective': np.float64(2478.4700000000003), 'mutation_rate': np.float64(0.7), 'current_iteration': 190, 'delta_F': 0.1}
# Step 20: action= 2, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 200, 'delta_F': 0.1}
# Step 21: action= 2, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 210, 'delta_F': 0.1}
# Step 22: action= 0, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 220, 'delta_F': 0.1}
# Step 23: action= 2, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 230, 'delta_F': 0.1}
# Step 24: action= 0, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 240, 'delta_F': 0.1}
# Step 25: action= 1, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 250, 'delta_F': 0.1}
# Step 26: action= 0, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 260, 'delta_F': 0.1}
# Step 27: action= 0, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 270, 'delta_F': 0.1}
# Step 28: action= 2, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 280, 'delta_F': 0.1}
# Step 29: action= 2, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 290, 'delta_F': 0.1}
# Step 30: action= 2, Reward=-2462.42, Terminated=False, Truncated=False, info={'objective': np.float64(2462.4190000000003), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 300, 'delta_F': 0.1}
# ...
# Step 23: action= 1, Reward=-1870.04, Terminated=False, Truncated=False, info={'objective': np.float64(1870.0449999999998), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 230, 'delta_F': 0.1}
# Step 24: action= 1, Reward=-1865.34, Terminated=False, Truncated=False, info={'objective': np.float64(1865.3379999999997), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 240, 'delta_F': 0.1}
# Step 25: action= 1, Reward=-1865.34, Terminated=False, Truncated=False, info={'objective': np.float64(1865.3379999999997), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 250, 'delta_F': 0.1}
# Step 26: action= 0, Reward=-1865.34, Terminated=False, Truncated=False, info={'objective': np.float64(1865.3379999999997), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 260, 'delta_F': 0.1}
# Step 27: action= 0, Reward=-1856.13, Terminated=False, Truncated=False, info={'objective': np.float64(1856.1269999999997), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 270, 'delta_F': 0.1}
# Step 28: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 280, 'delta_F': 0.1}
# Step 29: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 290, 'delta_F': 0.1}
# Step 30: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 300, 'delta_F': 0.1}
# Step 31: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 310, 'delta_F': 0.1}
# Step 32: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 320, 'delta_F': 0.1}
# Step 33: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 330, 'delta_F': 0.1}
# Step 34: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 340, 'delta_F': 0.1}
# Step 35: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 350, 'delta_F': 0.1}
# Step 36: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 360, 'delta_F': 0.1}
# Step 37: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 370, 'delta_F': 0.1}
# Step 38: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 380, 'delta_F': 0.1}
# Step 39: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 390, 'delta_F': 0.1}
# Step 40: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 400, 'delta_F': 0.1}
# Step 41: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.10000000000000003), 'current_iteration': 410, 'delta_F': 0.1}
# Step 42: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.20000000000000004), 'current_iteration': 420, 'delta_F': 0.1}
# Step 43: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 430, 'delta_F': 0.1}
# Step 44: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.4), 'current_iteration': 440, 'delta_F': 0.1}
# Step 45: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 450, 'delta_F': 0.1}
# Step 46: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.4), 'current_iteration': 460, 'delta_F': 0.1}
# Step 47: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.5), 'current_iteration': 470, 'delta_F': 0.1}
# Step 48: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.4), 'current_iteration': 480, 'delta_F': 0.1}
# Step 49: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 490, 'delta_F': 0.1}
# Step 50: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.4), 'current_iteration': 500, 'delta_F': 0.1}
# Step 51: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.4), 'current_iteration': 510, 'delta_F': 0.1}
# Step 52: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.30000000000000004), 'current_iteration': 520, 'delta_F': 0.1}
# Step 53: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.4), 'current_iteration': 530, 'delta_F': 0.1}
# Step 54: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.5), 'current_iteration': 540, 'delta_F': 0.1}
# Step 55: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.6), 'current_iteration': 550, 'delta_F': 0.1}
# Step 56: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 560, 'delta_F': 0.1}
# Step 57: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 570, 'delta_F': 0.1}
# Step 58: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 580, 'delta_F': 0.1}
# Step 59: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.6), 'current_iteration': 590, 'delta_F': 0.1}
# Step 60: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 600, 'delta_F': 0.1}
# Step 61: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 610, 'delta_F': 0.1}
# Step 62: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.6), 'current_iteration': 620, 'delta_F': 0.1}
# Step 63: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.5), 'current_iteration': 630, 'delta_F': 0.1}
# Step 64: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.6), 'current_iteration': 640, 'delta_F': 0.1}
# Step 65: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.5), 'current_iteration': 650, 'delta_F': 0.1}
# Step 66: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.5), 'current_iteration': 660, 'delta_F': 0.1}
# Step 67: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.6), 'current_iteration': 670, 'delta_F': 0.1}
# Step 68: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.5), 'current_iteration': 680, 'delta_F': 0.1}
# Step 69: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.6), 'current_iteration': 690, 'delta_F': 0.1}
# Step 70: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.6), 'current_iteration': 700, 'delta_F': 0.1}
# Step 71: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 710, 'delta_F': 0.1}
# Step 72: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 720, 'delta_F': 0.1}
# Step 73: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 730, 'delta_F': 0.1}
# Step 74: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 740, 'delta_F': 0.1}
# Step 75: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 750, 'delta_F': 0.1}
# Step 76: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 760, 'delta_F': 0.1}
# Step 77: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 770, 'delta_F': 0.1}
# Step 78: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 780, 'delta_F': 0.1}
# Step 79: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.6), 'current_iteration': 790, 'delta_F': 0.1}
# Step 80: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 800, 'delta_F': 0.1}
# Step 81: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 810, 'delta_F': 0.1}
# Step 82: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 820, 'delta_F': 0.1}
# Step 83: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 830, 'delta_F': 0.1}
# Step 84: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 840, 'delta_F': 0.1}
# Step 85: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 850, 'delta_F': 0.1}
# Step 86: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 860, 'delta_F': 0.1}
# Step 87: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 870, 'delta_F': 0.1}
# Step 88: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 880, 'delta_F': 0.1}
# Step 89: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7), 'current_iteration': 890, 'delta_F': 0.1}
# Step 90: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 900, 'delta_F': 0.1}
# Step 91: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 910, 'delta_F': 0.1}
# Step 92: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 920, 'delta_F': 0.1}
# Step 93: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 930, 'delta_F': 0.1}
# Step 94: action= 1, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 940, 'delta_F': 0.1}
# Step 95: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 950, 'delta_F': 0.1}
# Step 96: action= 0, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 960, 'delta_F': 0.1}
# Step 97: action= 2, Reward=-1851.56, Terminated=False, Truncated=False, info={'objective': np.float64(1851.561), 'mutation_rate': np.float64(0.9999999999999999), 'current_iteration': 970, 'delta_F': 0.1}
# Step 98: action= 1, Reward=-1825.33, Terminated=False, Truncated=False, info={'objective': np.float64(1825.3279999999997), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 980, 'delta_F': 0.1}
# Step 99: action= 1, Reward=-1825.33, Terminated=False, Truncated=False, info={'objective': np.float64(1825.3279999999997), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 990, 'delta_F': 0.1}
# Step 100: action= 0, Reward=-1825.33, Terminated=False, Truncated=False, info={'objective': np.float64(1825.3279999999997), 'mutation_rate': np.float64(0.7999999999999999), 'current_iteration': 1000, 'delta_F': 0.1}
# Step 101: action= 2, Reward=-1825.33, Terminated=True, Truncated=True, info={'objective': np.float64(1825.3279999999997), 'mutation_rate': np.float64(0.8999999999999999), 'current_iteration': 1010, 'delta_F': 0.1}
# Episode finished after 101 steps with total reward: -197467.01

# %%
for i in range(n_epi):
    reward_arr = epi[i]
    sns.lineplot(reward_arr)

# %%
n_epi = 10
epi = []

for _ in range(n_epi):
    total_reward = 0.0
    total_steps = 0
    curState, _ = env.reset()
    reward_arr = []
    state = env.convert_to_flat_index(
        (
            curState["objective"],
            curState["mutation_rate"],
            curState["current_iteration"],
        )
    )

    done = False
    while not done:
        action = policy[state]
        curState, reward, terminated, truncated, info = env.step(action)
        state = env.convert_to_flat_index(
            (
                curState["objective"],
                curState["mutation_rate"],
                curState["current_iteration"],
            )
        )

        total_reward += reward
        reward_arr.append(-reward)


        total_steps += 1
        done = terminated or truncated
        print(
            f"Step {total_steps:2d}: action={action:2d}, Reward={reward:5.2f}, "
            f"Terminated={terminated}, Truncated={truncated}, info={info}"
        )

    print(
        f"Episode finished after {total_steps} steps with total reward: {total_reward:.2f}"
    )

    env.close()
    epi.append(reward_arr)
# Out:
# Step  1: action= 1, Reward=-4046.92, Terminated=False, Truncated=False, info={'objective': np.float64(4046.916), 'mutation_rate': np.float64(0.4), 'current_iteration': 10, 'delta_F': 0.1}
# Step  2: action= 2, Reward=-4046.92, Terminated=False, Truncated=False, info={'objective': np.float64(4046.916), 'mutation_rate': np.float64(0.5), 'current_iteration': 20, 'delta_F': 0.1}
# Step  3: action= 1, Reward=-3846.56, Terminated=False, Truncated=False, info={'objective': np.float64(3846.563999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 30, 'delta_F': 0.1}
# Step  4: action= 2, Reward=-3766.31, Terminated=False, Truncated=False, info={'objective': np.float64(3766.314999999999), 'mutation_rate': np.float64(0.5), 'current_iteration': 40, 'delta_F': 0.1}
# Step  5: action= 1, Reward=-3485.41, Terminated=False, Truncated=False, info={'objective': np.float64(3485.408999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 50, 'delta_F': 0.1}
# Step  6: action= 2, Reward=-2940.62, Terminated=False, Truncated=False, info={'objective': np.float64(2940.623), 'mutation_rate': np.float64(0.5), 'current_iteration': 60, 'delta_F': 0.1}
# Step  7: action= 1, Reward=-2608.55, Terminated=False, Truncated=False, info={'objective': np.float64(2608.547), 'mutation_rate': np.float64(0.4), 'current_iteration': 70, 'delta_F': 0.1}
# Step  8: action= 2, Reward=-2608.55, Terminated=False, Truncated=False, info={'objective': np.float64(2608.547), 'mutation_rate': np.float64(0.5), 'current_iteration': 80, 'delta_F': 0.1}
# Step  9: action= 1, Reward=-2608.55, Terminated=False, Truncated=False, info={'objective': np.float64(2608.547), 'mutation_rate': np.float64(0.4), 'current_iteration': 90, 'delta_F': 0.1}
# Step 10: action= 2, Reward=-2608.55, Terminated=False, Truncated=False, info={'objective': np.float64(2608.547), 'mutation_rate': np.float64(0.5), 'current_iteration': 100, 'delta_F': 0.1}
# Step 11: action= 1, Reward=-2552.36, Terminated=False, Truncated=False, info={'objective': np.float64(2552.358999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 110, 'delta_F': 0.1}
# Step 12: action= 0, Reward=-2403.59, Terminated=False, Truncated=False, info={'objective': np.float64(2403.5899999999992), 'mutation_rate': np.float64(0.4), 'current_iteration': 120, 'delta_F': 0.1}
# Step 13: action= 0, Reward=-2403.59, Terminated=False, Truncated=False, info={'objective': np.float64(2403.5899999999992), 'mutation_rate': np.float64(0.4), 'current_iteration': 130, 'delta_F': 0.1}
# Step 14: action= 0, Reward=-2338.51, Terminated=False, Truncated=False, info={'objective': np.float64(2338.5079999999994), 'mutation_rate': np.float64(0.4), 'current_iteration': 140, 'delta_F': 0.1}
# Step 15: action= 0, Reward=-2338.51, Terminated=False, Truncated=False, info={'objective': np.float64(2338.5079999999994), 'mutation_rate': np.float64(0.4), 'current_iteration': 150, 'delta_F': 0.1}
# Step 16: action= 0, Reward=-2231.54, Terminated=False, Truncated=False, info={'objective': np.float64(2231.542), 'mutation_rate': np.float64(0.4), 'current_iteration': 160, 'delta_F': 0.1}
# Step 17: action= 0, Reward=-2185.87, Terminated=False, Truncated=False, info={'objective': np.float64(2185.868), 'mutation_rate': np.float64(0.4), 'current_iteration': 170, 'delta_F': 0.1}
# Step 18: action= 0, Reward=-2185.87, Terminated=False, Truncated=False, info={'objective': np.float64(2185.868), 'mutation_rate': np.float64(0.4), 'current_iteration': 180, 'delta_F': 0.1}
# Step 19: action= 0, Reward=-2179.17, Terminated=False, Truncated=False, info={'objective': np.float64(2179.1670000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 190, 'delta_F': 0.1}
# Step 20: action= 0, Reward=-2167.88, Terminated=False, Truncated=False, info={'objective': np.float64(2167.8830000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 200, 'delta_F': 0.1}
# Step 21: action= 0, Reward=-2166.94, Terminated=False, Truncated=False, info={'objective': np.float64(2166.9370000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 210, 'delta_F': 0.1}
# Step 22: action= 0, Reward=-2154.03, Terminated=False, Truncated=False, info={'objective': np.float64(2154.026), 'mutation_rate': np.float64(0.4), 'current_iteration': 220, 'delta_F': 0.1}
# Step 23: action= 0, Reward=-2124.91, Terminated=False, Truncated=False, info={'objective': np.float64(2124.912), 'mutation_rate': np.float64(0.4), 'current_iteration': 230, 'delta_F': 0.1}
# Step 24: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 240, 'delta_F': 0.1}
# Step 25: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 250, 'delta_F': 0.1}
# Step 26: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 260, 'delta_F': 0.1}
# Step 27: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 270, 'delta_F': 0.1}
# Step 28: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 280, 'delta_F': 0.1}
# Step 29: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 290, 'delta_F': 0.1}
# Step 30: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 300, 'delta_F': 0.1}
# Step 31: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 310, 'delta_F': 0.1}
# Step 32: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 320, 'delta_F': 0.1}
# Step 33: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 330, 'delta_F': 0.1}
# Step 34: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 340, 'delta_F': 0.1}
# Step 35: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 350, 'delta_F': 0.1}
# Step 36: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 360, 'delta_F': 0.1}
# Step 37: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 370, 'delta_F': 0.1}
# Step 38: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 380, 'delta_F': 0.1}
# Step 39: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 390, 'delta_F': 0.1}
# Step 40: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 400, 'delta_F': 0.1}
# Step 41: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 410, 'delta_F': 0.1}
# Step 42: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 420, 'delta_F': 0.1}
# Step 43: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 430, 'delta_F': 0.1}
# Step 44: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 440, 'delta_F': 0.1}
# Step 45: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 450, 'delta_F': 0.1}
# Step 46: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 460, 'delta_F': 0.1}
# Step 47: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 470, 'delta_F': 0.1}
# Step 48: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 480, 'delta_F': 0.1}
# Step 49: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 490, 'delta_F': 0.1}
# Step 50: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 500, 'delta_F': 0.1}
# Step 51: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 510, 'delta_F': 0.1}
# Step 52: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 520, 'delta_F': 0.1}
# Step 53: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 530, 'delta_F': 0.1}
# Step 54: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 540, 'delta_F': 0.1}
# Step 55: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 550, 'delta_F': 0.1}
# Step 56: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 560, 'delta_F': 0.1}
# Step 57: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 570, 'delta_F': 0.1}
# Step 58: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 580, 'delta_F': 0.1}
# Step 59: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 590, 'delta_F': 0.1}
# Step 60: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 600, 'delta_F': 0.1}
# Step 61: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 610, 'delta_F': 0.1}
# Step 62: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 620, 'delta_F': 0.1}
# Step 63: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 630, 'delta_F': 0.1}
# Step 64: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 640, 'delta_F': 0.1}
# Step 65: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 650, 'delta_F': 0.1}
# Step 66: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 660, 'delta_F': 0.1}
# Step 67: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 670, 'delta_F': 0.1}
# Step 68: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 680, 'delta_F': 0.1}
# Step 69: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 690, 'delta_F': 0.1}
# Step 70: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 700, 'delta_F': 0.1}
# Step 71: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 710, 'delta_F': 0.1}
# Step 72: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 720, 'delta_F': 0.1}
# Step 73: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 730, 'delta_F': 0.1}
# Step 74: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 740, 'delta_F': 0.1}
# Step 75: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 750, 'delta_F': 0.1}
# Step 76: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 760, 'delta_F': 0.1}
# Step 77: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 770, 'delta_F': 0.1}
# Step 78: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 780, 'delta_F': 0.1}
# Step 79: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 790, 'delta_F': 0.1}
# Step 80: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 800, 'delta_F': 0.1}
# Step 81: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 810, 'delta_F': 0.1}
# Step 82: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 820, 'delta_F': 0.1}
# Step 83: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 830, 'delta_F': 0.1}
# Step 84: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 840, 'delta_F': 0.1}
# Step 85: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 850, 'delta_F': 0.1}
# Step 86: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 860, 'delta_F': 0.1}
# Step 87: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 870, 'delta_F': 0.1}
# Step 88: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 880, 'delta_F': 0.1}
# Step 89: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 890, 'delta_F': 0.1}
# Step 90: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 900, 'delta_F': 0.1}
# Step 91: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 910, 'delta_F': 0.1}
# Step 92: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 920, 'delta_F': 0.1}
# Step 93: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 930, 'delta_F': 0.1}
# Step 94: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 940, 'delta_F': 0.1}
# Step 95: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 950, 'delta_F': 0.1}
# Step 96: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 960, 'delta_F': 0.1}
# Step 97: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 970, 'delta_F': 0.1}
# Step 98: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 980, 'delta_F': 0.1}
# Step 99: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 990, 'delta_F': 0.1}
# Step 100: action= 0, Reward=-2085.46, Terminated=False, Truncated=False, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 1000, 'delta_F': 0.1}
# Step 101: action= 0, Reward=-2085.46, Terminated=True, Truncated=True, info={'objective': np.float64(2085.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 1010, 'delta_F': 0.1}
# Episode finished after 101 steps with total reward: -224665.72
# Step  1: action= 1, Reward=-4037.93, Terminated=False, Truncated=False, info={'objective': np.float64(4037.9339999999993), 'mutation_rate': np.float64(0.4), 'current_iteration': 10, 'delta_F': 0.1}
# Step  2: action= 2, Reward=-4037.93, Terminated=False, Truncated=False, info={'objective': np.float64(4037.9339999999993), 'mutation_rate': np.float64(0.5), 'current_iteration': 20, 'delta_F': 0.1}
# Step  3: action= 1, Reward=-3960.06, Terminated=False, Truncated=False, info={'objective': np.float64(3960.061999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 30, 'delta_F': 0.1}
# Step  4: action= 2, Reward=-3946.44, Terminated=False, Truncated=False, info={'objective': np.float64(3946.441), 'mutation_rate': np.float64(0.5), 'current_iteration': 40, 'delta_F': 0.1}
# Step  5: action= 1, Reward=-3946.44, Terminated=False, Truncated=False, info={'objective': np.float64(3946.441), 'mutation_rate': np.float64(0.4), 'current_iteration': 50, 'delta_F': 0.1}
# Step  6: action= 2, Reward=-3331.24, Terminated=False, Truncated=False, info={'objective': np.float64(3331.2390000000005), 'mutation_rate': np.float64(0.5), 'current_iteration': 60, 'delta_F': 0.1}
# Step  7: action= 1, Reward=-2956.20, Terminated=False, Truncated=False, info={'objective': np.float64(2956.2030000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 70, 'delta_F': 0.1}
# Step  8: action= 2, Reward=-2814.25, Terminated=False, Truncated=False, info={'objective': np.float64(2814.246000000001), 'mutation_rate': np.float64(0.5), 'current_iteration': 80, 'delta_F': 0.1}
# Step  9: action= 1, Reward=-2666.10, Terminated=False, Truncated=False, info={'objective': np.float64(2666.098), 'mutation_rate': np.float64(0.4), 'current_iteration': 90, 'delta_F': 0.1}
# Step 10: action= 2, Reward=-2538.93, Terminated=False, Truncated=False, info={'objective': np.float64(2538.9289999999996), 'mutation_rate': np.float64(0.5), 'current_iteration': 100, 'delta_F': 0.1}
# Step 11: action= 1, Reward=-2538.93, Terminated=False, Truncated=False, info={'objective': np.float64(2538.9289999999996), 'mutation_rate': np.float64(0.4), 'current_iteration': 110, 'delta_F': 0.1}
# Step 12: action= 0, Reward=-2538.93, Terminated=False, Truncated=False, info={'objective': np.float64(2538.9289999999996), 'mutation_rate': np.float64(0.4), 'current_iteration': 120, 'delta_F': 0.1}
# Step 13: action= 0, Reward=-2538.93, Terminated=False, Truncated=False, info={'objective': np.float64(2538.9289999999996), 'mutation_rate': np.float64(0.4), 'current_iteration': 130, 'delta_F': 0.1}
# Step 14: action= 0, Reward=-2538.93, Terminated=False, Truncated=False, info={'objective': np.float64(2538.9289999999996), 'mutation_rate': np.float64(0.4), 'current_iteration': 140, 'delta_F': 0.1}
# Step 15: action= 0, Reward=-2508.29, Terminated=False, Truncated=False, info={'objective': np.float64(2508.2930000000006), 'mutation_rate': np.float64(0.4), 'current_iteration': 150, 'delta_F': 0.1}
# Step 16: action= 0, Reward=-2508.29, Terminated=False, Truncated=False, info={'objective': np.float64(2508.2930000000006), 'mutation_rate': np.float64(0.4), 'current_iteration': 160, 'delta_F': 0.1}
# Step 17: action= 0, Reward=-2508.29, Terminated=False, Truncated=False, info={'objective': np.float64(2508.2930000000006), 'mutation_rate': np.float64(0.4), 'current_iteration': 170, 'delta_F': 0.1}
# Step 18: action= 0, Reward=-2496.91, Terminated=False, Truncated=False, info={'objective': np.float64(2496.908), 'mutation_rate': np.float64(0.4), 'current_iteration': 180, 'delta_F': 0.1}
# Step 19: action= 0, Reward=-2453.94, Terminated=False, Truncated=False, info={'objective': np.float64(2453.9390000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 190, 'delta_F': 0.1}
# Step 20: action= 0, Reward=-2453.94, Terminated=False, Truncated=False, info={'objective': np.float64(2453.9390000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 200, 'delta_F': 0.1}
# Step 21: action= 0, Reward=-2451.82, Terminated=False, Truncated=False, info={'objective': np.float64(2451.8210000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 210, 'delta_F': 0.1}
# Step 22: action= 0, Reward=-2448.50, Terminated=False, Truncated=False, info={'objective': np.float64(2448.498000000001), 'mutation_rate': np.float64(0.4), 'current_iteration': 220, 'delta_F': 0.1}
# Step 23: action= 0, Reward=-2424.62, Terminated=False, Truncated=False, info={'objective': np.float64(2424.6190000000006), 'mutation_rate': np.float64(0.4), 'current_iteration': 230, 'delta_F': 0.1}
# Step 24: action= 0, Reward=-2424.62, Terminated=False, Truncated=False, info={'objective': np.float64(2424.6190000000006), 'mutation_rate': np.float64(0.4), 'current_iteration': 240, 'delta_F': 0.1}
# Step 25: action= 0, Reward=-2411.87, Terminated=False, Truncated=False, info={'objective': np.float64(2411.869), 'mutation_rate': np.float64(0.4), 'current_iteration': 250, 'delta_F': 0.1}
# Step 26: action= 0, Reward=-2411.87, Terminated=False, Truncated=False, info={'objective': np.float64(2411.869), 'mutation_rate': np.float64(0.4), 'current_iteration': 260, 'delta_F': 0.1}
# Step 27: action= 0, Reward=-2402.46, Terminated=False, Truncated=False, info={'objective': np.float64(2402.461), 'mutation_rate': np.float64(0.4), 'current_iteration': 270, 'delta_F': 0.1}
# Step 28: action= 0, Reward=-2402.46, Terminated=False, Truncated=False, info={'objective': np.float64(2402.461), 'mutation_rate': np.float64(0.4), 'current_iteration': 280, 'delta_F': 0.1}
# Step 29: action= 0, Reward=-2387.23, Terminated=False, Truncated=False, info={'objective': np.float64(2387.2250000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 290, 'delta_F': 0.1}
# Step 30: action= 0, Reward=-2387.23, Terminated=False, Truncated=False, info={'objective': np.float64(2387.2250000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 300, 'delta_F': 0.1}
# Step 31: action= 0, Reward=-2387.23, Terminated=False, Truncated=False, info={'objective': np.float64(2387.2250000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 310, 'delta_F': 0.1}
# Step 32: action= 0, Reward=-2387.23, Terminated=False, Truncated=False, info={'objective': np.float64(2387.2250000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 320, 'delta_F': 0.1}
# Step 33: action= 0, Reward=-2387.23, Terminated=False, Truncated=False, info={'objective': np.float64(2387.2250000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 330, 'delta_F': 0.1}
# Step 34: action= 0, Reward=-2387.23, Terminated=False, Truncated=False, info={'objective': np.float64(2387.2250000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 340, 'delta_F': 0.1}
# Step 35: action= 0, Reward=-2387.23, Terminated=False, Truncated=False, info={'objective': np.float64(2387.2250000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 350, 'delta_F': 0.1}
# Step 36: action= 0, Reward=-2387.23, Terminated=False, Truncated=False, info={'objective': np.float64(2387.2250000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 360, 'delta_F': 0.1}
# Step 37: action= 0, Reward=-2384.64, Terminated=False, Truncated=False, info={'objective': np.float64(2384.6420000000007), 'mutation_rate': np.float64(0.4), 'current_iteration': 370, 'delta_F': 0.1}
# Step 38: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 380, 'delta_F': 0.1}
# Step 39: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 390, 'delta_F': 0.1}
# Step 40: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 400, 'delta_F': 0.1}
# Step 41: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 410, 'delta_F': 0.1}
# Step 42: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 420, 'delta_F': 0.1}
# Step 43: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 430, 'delta_F': 0.1}
# Step 44: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 440, 'delta_F': 0.1}
# Step 45: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 450, 'delta_F': 0.1}
# Step 46: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 460, 'delta_F': 0.1}
# Step 47: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 470, 'delta_F': 0.1}
# Step 48: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 480, 'delta_F': 0.1}
# Step 49: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 490, 'delta_F': 0.1}
# Step 50: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 500, 'delta_F': 0.1}
# Step 51: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 510, 'delta_F': 0.1}
# Step 52: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 520, 'delta_F': 0.1}
# Step 53: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 530, 'delta_F': 0.1}
# Step 54: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 540, 'delta_F': 0.1}
# Step 55: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 550, 'delta_F': 0.1}
# Step 56: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 560, 'delta_F': 0.1}
# Step 57: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 570, 'delta_F': 0.1}
# Step 58: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 580, 'delta_F': 0.1}
# Step 59: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 590, 'delta_F': 0.1}
# Step 60: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 600, 'delta_F': 0.1}
# Step 61: action= 0, Reward=-2375.37, Terminated=False, Truncated=False, info={'objective': np.float64(2375.3700000000003), 'mutation_rate': np.float64(0.4), 'current_iteration': 610, 'delta_F': 0.1}
# Step 62: action= 0, Reward=-2370.60, Terminated=False, Truncated=False, info={'objective': np.float64(2370.6), 'mutation_rate': np.float64(0.4), 'current_iteration': 620, 'delta_F': 0.1}
# Step 63: action= 0, Reward=-2370.60, Terminated=False, Truncated=False, info={'objective': np.float64(2370.6), 'mutation_rate': np.float64(0.4), 'current_iteration': 630, 'delta_F': 0.1}
# Step 64: action= 0, Reward=-2370.60, Terminated=False, Truncated=False, info={'objective': np.float64(2370.6), 'mutation_rate': np.float64(0.4), 'current_iteration': 640, 'delta_F': 0.1}
# Step 65: action= 0, Reward=-2370.60, Terminated=False, Truncated=False, info={'objective': np.float64(2370.6), 'mutation_rate': np.float64(0.4), 'current_iteration': 650, 'delta_F': 0.1}
# Step 66: action= 0, Reward=-2370.46, Terminated=False, Truncated=False, info={'objective': np.float64(2370.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 660, 'delta_F': 0.1}
# Step 67: action= 0, Reward=-2370.46, Terminated=False, Truncated=False, info={'objective': np.float64(2370.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 670, 'delta_F': 0.1}
# Step 68: action= 0, Reward=-2370.46, Terminated=False, Truncated=False, info={'objective': np.float64(2370.462), 'mutation_rate': np.float64(0.4), 'current_iteration': 680, 'delta_F': 0.1}
# Step 69: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 690, 'delta_F': 0.1}
# Step 70: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 700, 'delta_F': 0.1}
# Step 71: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 710, 'delta_F': 0.1}
# Step 72: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 720, 'delta_F': 0.1}
# Step 73: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 730, 'delta_F': 0.1}
# Step 74: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 740, 'delta_F': 0.1}
# Step 75: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 750, 'delta_F': 0.1}
# Step 76: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 760, 'delta_F': 0.1}
# Step 77: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 770, 'delta_F': 0.1}
# Step 78: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 780, 'delta_F': 0.1}
# Step 79: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 790, 'delta_F': 0.1}
# Step 80: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 800, 'delta_F': 0.1}
# Step 81: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 810, 'delta_F': 0.1}
# Step 82: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 820, 'delta_F': 0.1}
# Step 83: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 830, 'delta_F': 0.1}
# Step 84: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 840, 'delta_F': 0.1}
# Step 85: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 850, 'delta_F': 0.1}
# Step 86: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 860, 'delta_F': 0.1}
# Step 87: action= 0, Reward=-2369.15, Terminated=False, Truncated=False, info={'objective': np.float64(2369.152), 'mutation_rate': np.float64(0.4), 'current_iteration': 870, 'delta_F': 0.1}
# Step 88: action= 0, Reward=-2364.96, Terminated=False, Truncated=False, info={'objective': np.float64(2364.957), 'mutation_rate': np.float64(0.4), 'current_iteration': 880, 'delta_F': 0.1}
# Step 89: action= 0, Reward=-2364.96, Terminated=False, Truncated=False, info={'objective': np.float64(2364.957), 'mutation_rate': np.float64(0.4), 'current_iteration': 890, 'delta_F': 0.1}
# Step 90: action= 0, Reward=-2364.96, Terminated=False, Truncated=False, info={'objective': np.float64(2364.957), 'mutation_rate': np.float64(0.4), 'current_iteration': 900, 'delta_F': 0.1}
# Step 91: action= 0, Reward=-2364.96, Terminated=False, Truncated=False, info={'objective': np.float64(2364.957), 'mutation_rate': np.float64(0.4), 'current_iteration': 910, 'delta_F': 0.1}
# Step 92: action= 0, Reward=-2364.96, Terminated=False, Truncated=False, info={'objective': np.float64(2364.957), 'mutation_rate': np.float64(0.4), 'current_iteration': 920, 'delta_F': 0.1}
# Step 93: action= 0, Reward=-2364.05, Terminated=False, Truncated=False, info={'objective': np.float64(2364.045), 'mutation_rate': np.float64(0.4), 'current_iteration': 930, 'delta_F': 0.1}
# Step 94: action= 0, Reward=-2364.05, Terminated=False, Truncated=False, info={'objective': np.float64(2364.045), 'mutation_rate': np.float64(0.4), 'current_iteration': 940, 'delta_F': 0.1}
# Step 95: action= 0, Reward=-2364.05, Terminated=False, Truncated=False, info={'objective': np.float64(2364.045), 'mutation_rate': np.float64(0.4), 'current_iteration': 950, 'delta_F': 0.1}
# Step 96: action= 0, Reward=-2364.05, Terminated=False, Truncated=False, info={'objective': np.float64(2364.045), 'mutation_rate': np.float64(0.4), 'current_iteration': 960, 'delta_F': 0.1}
# Step 97: action= 0, Reward=-2363.51, Terminated=False, Truncated=False, info={'objective': np.float64(2363.509), 'mutation_rate': np.float64(0.4), 'current_iteration': 970, 'delta_F': 0.1}
# Step 98: action= 0, Reward=-2363.51, Terminated=False, Truncated=False, info={'objective': np.float64(2363.509), 'mutation_rate': np.float64(0.4), 'current_iteration': 980, 'delta_F': 0.1}
# Step 99: action= 0, Reward=-2363.51, Terminated=False, Truncated=False, info={'objective': np.float64(2363.509), 'mutation_rate': np.float64(0.4), 'current_iteration': 990, 'delta_F': 0.1}
# Step 100: action= 0, Reward=-2363.51, Terminated=False, Truncated=False, info={'objective': np.float64(2363.509), 'mutation_rate': np.float64(0.4), 'current_iteration': 1000, 'delta_F': 0.1}
# Step 101: action= 0, Reward=-2363.51, Terminated=True, Truncated=True, info={'objective': np.float64(2363.509), 'mutation_rate': np.float64(0.4), 'current_iteration': 1010, 'delta_F': 0.1}
# Episode finished after 101 steps with total reward: -251896.63
# Step  1: action= 1, Reward=-4411.48, Terminated=False, Truncated=False, info={'objective': np.float64(4411.475999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 10, 'delta_F': 0.1}
# Step  2: action= 2, Reward=-3549.72, Terminated=False, Truncated=False, info={'objective': np.float64(3549.7189999999996), 'mutation_rate': np.float64(0.5), 'current_iteration': 20, 'delta_F': 0.1}
# Step  3: action= 1, Reward=-3451.15, Terminated=False, Truncated=False, info={'objective': np.float64(3451.147), 'mutation_rate': np.float64(0.4), 'current_iteration': 30, 'delta_F': 0.1}
# Step  4: action= 2, Reward=-3451.15, Terminated=False, Truncated=False, info={'objective': np.float64(3451.147), 'mutation_rate': np.float64(0.5), 'current_iteration': 40, 'delta_F': 0.1}
# Step  5: action= 1, Reward=-3090.82, Terminated=False, Truncated=False, info={'objective': np.float64(3090.823000000001), 'mutation_rate': np.float64(0.4), 'current_iteration': 50, 'delta_F': 0.1}
# Step  6: action= 2, Reward=-2836.44, Terminated=False, Truncated=False, info={'objective': np.float64(2836.4409999999993), 'mutation_rate': np.float64(0.5), 'current_iteration': 60, 'delta_F': 0.1}
# Step  7: action= 1, Reward=-2578.71, Terminated=False, Truncated=False, info={'objective': np.float64(2578.712), 'mutation_rate': np.float64(0.4), 'current_iteration': 70, 'delta_F': 0.1}
# Step  8: action= 2, Reward=-2578.71, Terminated=False, Truncated=False, info={'objective': np.float64(2578.712), 'mutation_rate': np.float64(0.5), 'current_iteration': 80, 'delta_F': 0.1}
# Step  9: action= 1, Reward=-2529.10, Terminated=False, Truncated=False, info={'objective': np.float64(2529.1010000000006), 'mutation_rate': np.float64(0.4), 'current_iteration': 90, 'delta_F': 0.1}
# Step 10: action= 2, Reward=-2498.07, Terminated=False, Truncated=False, info={'objective': np.float64(2498.0690000000004), 'mutation_rate': np.float64(0.5), 'current_iteration': 100, 'delta_F': 0.1}
# Step 11: action= 1, Reward=-2498.07, Terminated=False, Truncated=False, info={'objective': np.float64(2498.0690000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 110, 'delta_F': 0.1}
# Step 12: action= 0, Reward=-2498.07, Terminated=False, Truncated=False, info={'objective': np.float64(2498.0690000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 120, 'delta_F': 0.1}
# Step 13: action= 0, Reward=-2498.07, Terminated=False, Truncated=False, info={'objective': np.float64(2498.0690000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 130, 'delta_F': 0.1}
# Step 14: action= 0, Reward=-2498.07, Terminated=False, Truncated=False, info={'objective': np.float64(2498.0690000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 140, 'delta_F': 0.1}
# Step 15: action= 0, Reward=-2498.07, Terminated=False, Truncated=False, info={'objective': np.float64(2498.0690000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 150, 'delta_F': 0.1}
# Step 16: action= 0, Reward=-2498.07, Terminated=False, Truncated=False, info={'objective': np.float64(2498.0690000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 160, 'delta_F': 0.1}
# Step 17: action= 0, Reward=-2485.88, Terminated=False, Truncated=False, info={'objective': np.float64(2485.877), 'mutation_rate': np.float64(0.4), 'current_iteration': 170, 'delta_F': 0.1}
# Step 18: action= 0, Reward=-2485.88, Terminated=False, Truncated=False, info={'objective': np.float64(2485.877), 'mutation_rate': np.float64(0.4), 'current_iteration': 180, 'delta_F': 0.1}
# Step 19: action= 0, Reward=-2485.88, Terminated=False, Truncated=False, info={'objective': np.float64(2485.877), 'mutation_rate': np.float64(0.4), 'current_iteration': 190, 'delta_F': 0.1}
# Step 20: action= 0, Reward=-2485.88, Terminated=False, Truncated=False, info={'objective': np.float64(2485.877), 'mutation_rate': np.float64(0.4), 'current_iteration': 200, 'delta_F': 0.1}
# Step 21: action= 0, Reward=-2485.88, Terminated=False, Truncated=False, info={'objective': np.float64(2485.877), 'mutation_rate': np.float64(0.4), 'current_iteration': 210, 'delta_F': 0.1}
# Step 22: action= 0, Reward=-2469.78, Terminated=False, Truncated=False, info={'objective': np.float64(2469.7829999999994), 'mutation_rate': np.float64(0.4), 'current_iteration': 220, 'delta_F': 0.1}
# Step 23: action= 0, Reward=-2448.57, Terminated=False, Truncated=False, info={'objective': np.float64(2448.5710000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 230, 'delta_F': 0.1}
# Step 24: action= 0, Reward=-2448.57, Terminated=False, Truncated=False, info={'objective': np.float64(2448.5710000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 240, 'delta_F': 0.1}
# Step 25: action= 0, Reward=-2448.57, Terminated=False, Truncated=False, info={'objective': np.float64(2448.5710000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 250, 'delta_F': 0.1}
# Step 26: action= 0, Reward=-2448.57, Terminated=False, Truncated=False, info={'objective': np.float64(2448.5710000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 260, 'delta_F': 0.1}
# Step 27: action= 0, Reward=-2448.57, Terminated=False, Truncated=False, info={'objective': np.float64(2448.5710000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 270, 'delta_F': 0.1}
# Step 28: action= 0, Reward=-2448.57, Terminated=False, Truncated=False, info={'objective': np.float64(2448.5710000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 280, 'delta_F': 0.1}
# Step 29: action= 0, Reward=-2448.57, Terminated=False, Truncated=False, info={'objective': np.float64(2448.5710000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 290, 'delta_F': 0.1}
# Step 30: action= 0, Reward=-2448.57, Terminated=False, Truncated=False, info={'objective': np.float64(2448.5710000000004), 'mutation_rate': np.float64(0.4), 'current_iteration': 300, 'delta_F': 0.1}
# Step 31: action= 0, Reward=-2435.51, Terminated=False, Truncated=False, info={'objective': np.float64(2435.5070000000005), 'mutation_rate': np.float64(0.4), 'current_iteration': 310, 'delta_F': 0.1}
# Step 32: action= 0, Reward=-2435.51, Terminated=False, Truncated=False, info={'objective': np.float64(2435.5070000000005), 'mutation_rate': np.float64(0.4), 'current_iteration': 320, 'delta_F': 0.1}
# Step 33: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 330, 'delta_F': 0.1}
# Step 34: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 340, 'delta_F': 0.1}
# Step 35: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 350, 'delta_F': 0.1}
# Step 36: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 360, 'delta_F': 0.1}
# Step 37: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 370, 'delta_F': 0.1}
# Step 38: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 380, 'delta_F': 0.1}
# Step 39: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 390, 'delta_F': 0.1}
# Step 40: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 400, 'delta_F': 0.1}
# Step 41: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 410, 'delta_F': 0.1}
# Step 42: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 420, 'delta_F': 0.1}
# Step 43: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 430, 'delta_F': 0.1}
# Step 44: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 440, 'delta_F': 0.1}
# Step 45: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 450, 'delta_F': 0.1}
# Step 46: action= 0, Reward=-2334.65, Terminated=False, Truncated=False, info={'objective': np.float64(2334.6549999999997), 'mutation_rate': np.float64(0.4), 'current_iteration': 460, 'delta_F': 0.1}
# ...
# Step 20: action= 0, Reward=-2243.34, Terminated=False, Truncated=False, info={'objective': np.float64(2243.3420000000006), 'mutation_rate': np.float64(0.4), 'current_iteration': 200, 'delta_F': 0.1}
# Step 21: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 210, 'delta_F': 0.1}
# Step 22: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 220, 'delta_F': 0.1}
# Step 23: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 230, 'delta_F': 0.1}
# Step 24: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 240, 'delta_F': 0.1}
# Step 25: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 250, 'delta_F': 0.1}
# Step 26: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 260, 'delta_F': 0.1}
# Step 27: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 270, 'delta_F': 0.1}
# Step 28: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 280, 'delta_F': 0.1}
# Step 29: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 290, 'delta_F': 0.1}
# Step 30: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 300, 'delta_F': 0.1}
# Step 31: action= 0, Reward=-2147.76, Terminated=False, Truncated=False, info={'objective': np.float64(2147.7599999999998), 'mutation_rate': np.float64(0.4), 'current_iteration': 310, 'delta_F': 0.1}
# Step 32: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 320, 'delta_F': 0.1}
# Step 33: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 330, 'delta_F': 0.1}
# Step 34: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 340, 'delta_F': 0.1}
# Step 35: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 350, 'delta_F': 0.1}
# Step 36: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 360, 'delta_F': 0.1}
# Step 37: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 370, 'delta_F': 0.1}
# Step 38: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 380, 'delta_F': 0.1}
# Step 39: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 390, 'delta_F': 0.1}
# Step 40: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 400, 'delta_F': 0.1}
# Step 41: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 410, 'delta_F': 0.1}
# Step 42: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 420, 'delta_F': 0.1}
# Step 43: action= 0, Reward=-2080.10, Terminated=False, Truncated=False, info={'objective': np.float64(2080.103), 'mutation_rate': np.float64(0.4), 'current_iteration': 430, 'delta_F': 0.1}
# Step 44: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 440, 'delta_F': 0.1}
# Step 45: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 450, 'delta_F': 0.1}
# Step 46: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 460, 'delta_F': 0.1}
# Step 47: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 470, 'delta_F': 0.1}
# Step 48: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 480, 'delta_F': 0.1}
# Step 49: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 490, 'delta_F': 0.1}
# Step 50: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 500, 'delta_F': 0.1}
# Step 51: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 510, 'delta_F': 0.1}
# Step 52: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 520, 'delta_F': 0.1}
# Step 53: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 530, 'delta_F': 0.1}
# Step 54: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 540, 'delta_F': 0.1}
# Step 55: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 550, 'delta_F': 0.1}
# Step 56: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 560, 'delta_F': 0.1}
# Step 57: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 570, 'delta_F': 0.1}
# Step 58: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 580, 'delta_F': 0.1}
# Step 59: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 590, 'delta_F': 0.1}
# Step 60: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 600, 'delta_F': 0.1}
# Step 61: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 610, 'delta_F': 0.1}
# Step 62: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 620, 'delta_F': 0.1}
# Step 63: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 630, 'delta_F': 0.1}
# Step 64: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 640, 'delta_F': 0.1}
# Step 65: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 650, 'delta_F': 0.1}
# Step 66: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 660, 'delta_F': 0.1}
# Step 67: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 670, 'delta_F': 0.1}
# Step 68: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 680, 'delta_F': 0.1}
# Step 69: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 690, 'delta_F': 0.1}
# Step 70: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 700, 'delta_F': 0.1}
# Step 71: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 710, 'delta_F': 0.1}
# Step 72: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 720, 'delta_F': 0.1}
# Step 73: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 730, 'delta_F': 0.1}
# Step 74: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 740, 'delta_F': 0.1}
# Step 75: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 750, 'delta_F': 0.1}
# Step 76: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 760, 'delta_F': 0.1}
# Step 77: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 770, 'delta_F': 0.1}
# Step 78: action= 0, Reward=-2061.27, Terminated=False, Truncated=False, info={'objective': np.float64(2061.268), 'mutation_rate': np.float64(0.4), 'current_iteration': 780, 'delta_F': 0.1}
# Step 79: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 790, 'delta_F': 0.1}
# Step 80: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 800, 'delta_F': 0.1}
# Step 81: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 810, 'delta_F': 0.1}
# Step 82: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 820, 'delta_F': 0.1}
# Step 83: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 830, 'delta_F': 0.1}
# Step 84: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 840, 'delta_F': 0.1}
# Step 85: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 850, 'delta_F': 0.1}
# Step 86: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 860, 'delta_F': 0.1}
# Step 87: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 870, 'delta_F': 0.1}
# Step 88: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 880, 'delta_F': 0.1}
# Step 89: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 890, 'delta_F': 0.1}
# Step 90: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 900, 'delta_F': 0.1}
# Step 91: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 910, 'delta_F': 0.1}
# Step 92: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 920, 'delta_F': 0.1}
# Step 93: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 930, 'delta_F': 0.1}
# Step 94: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 940, 'delta_F': 0.1}
# Step 95: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 950, 'delta_F': 0.1}
# Step 96: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 960, 'delta_F': 0.1}
# Step 97: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 970, 'delta_F': 0.1}
# Step 98: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 980, 'delta_F': 0.1}
# Step 99: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 990, 'delta_F': 0.1}
# Step 100: action= 0, Reward=-2050.71, Terminated=False, Truncated=False, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 1000, 'delta_F': 0.1}
# Step 101: action= 0, Reward=-2050.71, Terminated=True, Truncated=True, info={'objective': np.float64(2050.713999999999), 'mutation_rate': np.float64(0.4), 'current_iteration': 1010, 'delta_F': 0.1}
# Episode finished after 101 steps with total reward: -229066.02

# %%
for i in range(n_epi):
    reward_arr = epi[i]
    sns.lineplot(reward_arr)
